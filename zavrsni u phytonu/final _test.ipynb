# %%
import requests
from datetime import datetime, timedelta
import time
import csv

def get_energy_data(api_key, city='Sarajevo', country='BA'):
    api_url = 'https://api.weatherbit.io/v2.0/current'

    current_datetime = datetime.now()
    current_day_start = datetime(current_datetime.year, current_datetime.month, current_datetime.day, 0, 0, 0)

    if current_datetime < current_day_start:
        current_day_start -= timedelta(days=1)

    params = {
        'city': city,
        'country': country,
        'key': api_key,
    }

    try:
        response = requests.get(api_url, params=params)

        if response.status_code == 200:
            data = response.json()

            # Otvori CSV fajl za pisanje
            with open('energy_data_vol2.csv', mode='a', newline='') as csv_file:
                fieldnames = ['Time'] + list(data['data'][0].keys())  # Dodajte 'Time' kao prvi stupac
                writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

                # Ako je fajl prazan, napiši zaglavlje
                if csv_file.tell() == 0:
                    writer.writeheader()

                for entry in data['data']:
                    # Dinamičko postavljanje vremena na trenutno vreme
                    time_str = datetime.now().strftime('%H:%M:%S')
                    entry['Time'] = time_str
                    #time_str = parse_datetime(entry.get('ob_time', '')).strftime('%H:%M:%S')
                    #entry['Time'] = time_str

                    # Dodajte red u CSV fajl
                    writer.writerow(entry)

                    # Isprintaj sve parametre za svaku opservaciju
                    print(f"Broj opservacija: {entry.get('count')}")
                    print(f"Geografska širina: {entry.get('lat')}")
                    print(f"Geografska duzna: {entry.get('lon')}")
                    print(f"Vrijeme izlaska sunca (UTC): {entry.get('sunrise')}")
                    print(f"Vrijeme zalaska sunca (UTC): {entry.get('sunset')}")
                    print(f"Vremenska zona: {entry.get('timezone')}")
                    print(f"ID stanice (zastarijelo): {entry.get('station')}")
                    print(f"Izvori podataka: {entry.get('sources')}")
                    print(f"Vrijeme posljednje opservacije: {entry.get('ob_time')}")
                    print(f"Posljednji vremenski ciklus (zastarijelo): {entry.get('datetime')}")
                    print(f"Vrijeme opservacije (Unix timestamp): {entry.get('ts')}")
                    print(f"Naziv grada: {entry.get('city_name')}")
                    print(f"Kod zemlje: {entry.get('country_code')}")
                    print(f"Kod države: {entry.get('state_code')}")
                    print(f"Pritisak: {entry.get('pres')} mb")
                    print(f"Pritisak na nivou mora: {entry.get('slp')} mb")
                    print(f"Brzina vjetra: {entry.get('wind_spd')} m/s")
                    print(f"Brzina vjetra (naleti): {entry.get('gust')} m/s")
                    print(f"Smijer vetra: {entry.get('wind_dir')} stepeni")
                    print(f"Kratki opis smijera vjetra: {entry.get('wind_cdir')}")
                    print(f"Puni opis smijera vjetra: {entry.get('wind_cdir_full')}")
                    print(f"Temperatura: {entry.get('temp')} °C")
                    print(f"Aparentna temperatura: {entry.get('app_temp')} °C")
                    print(f"Relativna vlaznost: {entry.get('rh')} %")
                    print(f"Tacka rose: {entry.get('dewpt')} °C")
                    print(f"Oblacnost: {entry.get('clouds')} %")
                    print(f"Dio dana: {entry.get('pod')} (d = dan / n = noć)")
                    print("Vremenski uslovi:")
                    print(f"   Ikona: {entry['weather'].get('icon')}")
                    print(f"   Kod: {entry['weather'].get('code')}")
                    print(f"   Opis: {entry['weather'].get('description')}")
                    print(f"Vidljivost: {entry.get('vis')} km")
                    print(f"Padavine: {entry.get('precip')} mm/h")
                    print(f"Snijeg: {entry.get('snow')} mm/h")
                    print(f"UV indeks: {entry.get('uv')}")
                    print(f"Indeks kvaliteta vazduha (AQI): {entry.get('aqi')}")
                    print(f"Difuzno horizontalno suncevo zracenje: {entry.get('dhi')} W/m^2")
                    print(f"Direktno normalno suncevo zracenje: {entry.get('dni')} W/m^2")
                    print(f"Globalno horizontalno suncevo zracenje: {entry.get('ghi')} W/m^2")
                    print(f"Procenjeno sunčevo zracenje: {entry.get('solar_rad')} W/m^2")
                    print(f"Solarni elevacioni ugao: {entry.get('elev_angle')} stepeni")
                    print(f"Solarni satni ugao (solarno podne) (zastarjelo): {entry.get('h_angle')} stepeni")

                    print("\n" + "-"*40 + "\n")

                # Provjera je li došlo do promjene dana
                if current_datetime == current_day_start:
                    print(f"Mjerenje za {current_day_start.date()} u {current_day_start.strftime('%H:%M:%S')}.")

        else:
            print(f'Error {response.status_code}: {response.text}')

    except Exception as e:
        print(f'Error: {e}')

def parse_datetime(dt_str):
    try:
        return datetime.strptime(dt_str, '%Y-%m-%d %H:%M:%S')
    except ValueError:
        return datetime.min

# Postavljanje periodičnog zadatka
while True:
    get_energy_data(api_key='abd79c512df344da80c500911fd874fe')
    time.sleep(900)  # Pauza od 900 sekundi (15 minuta) prije sljedećeg poziva
# Out:
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-22 23:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-22:23
# Vrijeme opservacije (Unix timestamp): 1703287800
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 940.5 mb
# Pritisak na nivou mora: 1002 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 2 °C
# Aparentna temperatura: 1.4 °C
# Relativna vlaznost: 100 %
# Tacka rose: 2 °C
# Oblacnost: 86 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: a05n
#    Kod: 741
#    Opis: Fog
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 95
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -69.39 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-22 23:38
# Posljednji vremenski ciklus (zastarijelo): 2023-12-22:23
# Vrijeme opservacije (Unix timestamp): 1703288285
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 940.5 mb
# Pritisak na nivou mora: 1002 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 2 °C
# Aparentna temperatura: 1.4 °C
# Relativna vlaznost: 100 %
# Tacka rose: 2 °C
# Oblacnost: 83 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: a05n
#    Kod: 741
#    Opis: Fog
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 91
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -64.53 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 00:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:00
# Vrijeme opservacije (Unix timestamp): 1703289600
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 940.2 mb
# Pritisak na nivou mora: 1002 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 1 °C
# Aparentna temperatura: 0.3 °C
# Relativna vlaznost: 100 %
# Tacka rose: 1 °C
# Oblacnost: 54 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: a05n
#    Kod: 741
#    Opis: Fog
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 91
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -64.53 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 00:08
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:00
# Vrijeme opservacije (Unix timestamp): 1703290087
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 940.2 mb
# Pritisak na nivou mora: 1002 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 1 °C
# Aparentna temperatura: 0.3 °C
# Relativna vlaznost: 100 %
# Tacka rose: 1 °C
# Oblacnost: 56 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: a05n
#    Kod: 741
#    Opis: Fog
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 91
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -64.53 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 00:23
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:00
# Vrijeme opservacije (Unix timestamp): 1703290988
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 940.2 mb
# Pritisak na nivou mora: 1002 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 1 °C
# Aparentna temperatura: 0.3 °C
# Relativna vlaznost: 100 %
# Tacka rose: 1 °C
# Oblacnost: 80 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: a05n
#    Kod: 741
#    Opis: Fog
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 91
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -64.53 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 00:38
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:00
# Vrijeme opservacije (Unix timestamp): 1703291889
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 939.3 mb
# Pritisak na nivou mora: 1001 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 1 °C
# Aparentna temperatura: 1.7 °C
# Relativna vlaznost: 100 %
# Tacka rose: 1 °C
# Oblacnost: 85 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: a05n
#    Kod: 741
#    Opis: Fog
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 100
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -55.78 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 01:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:01
# Vrijeme opservacije (Unix timestamp): 1703293200
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 940.2 mb
# Pritisak na nivou mora: 1002 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 1 °C
# Aparentna temperatura: 0.3 °C
# Relativna vlaznost: 100 %
# Tacka rose: 1 °C
# Oblacnost: 80 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: a05n
#    Kod: 741
#    Opis: Fog
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 100
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -55.78 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 01:08
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:01
# Vrijeme opservacije (Unix timestamp): 1703293691
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 940.2 mb
# Pritisak na nivou mora: 1002 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 1 °C
# Aparentna temperatura: 0.3 °C
# Relativna vlaznost: 100 %
# Tacka rose: 1 °C
# Oblacnost: 80 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: a05n
#    Kod: 741
#    Opis: Fog
# Vidljivost: 7 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 100
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -55.78 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 01:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:01
# Vrijeme opservacije (Unix timestamp): 1703295000
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 940.2 mb
# Pritisak na nivou mora: 1002 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 1 °C
# Aparentna temperatura: -1.4 °C
# Relativna vlaznost: 100 %
# Tacka rose: 1 °C
# Oblacnost: 80 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: a05n
#    Kod: 741
#    Opis: Fog
# Vidljivost: 7 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 100
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -55.78 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 01:38
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:01
# Vrijeme opservacije (Unix timestamp): 1703295493
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 940.2 mb
# Pritisak na nivou mora: 1002 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 1 °C
# Aparentna temperatura: -1.4 °C
# Relativna vlaznost: 100 %
# Tacka rose: 1 °C
# Oblacnost: 50 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: a05n
#    Kod: 741
#    Opis: Fog
# Vidljivost: 7 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 107
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -45.51 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 02:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:02
# Vrijeme opservacije (Unix timestamp): 1703296800
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 939.3 mb
# Pritisak na nivou mora: 1001 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 140 stepeni
# Kratki opis smijera vjetra: SE
# Puni opis smijera vjetra: southeast
# Temperatura: 1 °C
# Aparentna temperatura: -1.4 °C
# Relativna vlaznost: 100 %
# Tacka rose: 1 °C
# Oblacnost: 42 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: a05n
#    Kod: 741
#    Opis: Fog
# Vidljivost: 7 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 121
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -45.51 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 02:08
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:02
# Vrijeme opservacije (Unix timestamp): 1703297295
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 939.3 mb
# Pritisak na nivou mora: 1001 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 140 stepeni
# Kratki opis smijera vjetra: SE
# Puni opis smijera vjetra: southeast
# Temperatura: 1 °C
# Aparentna temperatura: -1.4 °C
# Relativna vlaznost: 100 %
# Tacka rose: 1 °C
# Oblacnost: 42 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: a05n
#    Kod: 741
#    Opis: Fog
# Vidljivost: 7 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 121
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -45.51 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 02:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:02
# Vrijeme opservacije (Unix timestamp): 1703298600
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 940.2 mb
# Pritisak na nivou mora: 1001 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 5 °C
# Aparentna temperatura: 3.3 °C
# Relativna vlaznost: 75 %
# Tacka rose: 0.9 °C
# Oblacnost: 42 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 7 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 121
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -45.51 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 02:38
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:02
# Vrijeme opservacije (Unix timestamp): 1703299097
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 940.2 mb
# Pritisak na nivou mora: 1001 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 5 °C
# Aparentna temperatura: 3.3 °C
# Relativna vlaznost: 75 %
# Tacka rose: 0.9 °C
# Oblacnost: 42 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 7 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 134
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -34.76 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 03:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:03
# Vrijeme opservacije (Unix timestamp): 1703300400
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 940.2 mb
# Pritisak na nivou mora: 1001 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 5 °C
# Aparentna temperatura: 3.3 °C
# Relativna vlaznost: 75 %
# Tacka rose: 0.9 °C
# Oblacnost: 42 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 7 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 97
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -34.76 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 03:08
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:03
# Vrijeme opservacije (Unix timestamp): 1703300899
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 940.2 mb
# Pritisak na nivou mora: 1001 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 5 °C
# Aparentna temperatura: 3.3 °C
# Relativna vlaznost: 75 %
# Tacka rose: 0.9 °C
# Oblacnost: 42 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 3 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 97
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -34.76 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 03:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:03
# Vrijeme opservacije (Unix timestamp): 1703302200
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 941.5 mb
# Pritisak na nivou mora: 1002 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 7 °C
# Aparentna temperatura: 5.7 °C
# Relativna vlaznost: 65 %
# Tacka rose: 0.9 °C
# Oblacnost: 40 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 801
#    Opis: Few clouds
# Vidljivost: 3 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 97
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -34.76 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 03:38
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:03
# Vrijeme opservacije (Unix timestamp): 1703302701
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 941.5 mb
# Pritisak na nivou mora: 1002 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 7 °C
# Aparentna temperatura: 5.7 °C
# Relativna vlaznost: 65 %
# Tacka rose: 0.9 °C
# Oblacnost: 40 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 801
#    Opis: Few clouds
# Vidljivost: 3 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 97
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -24 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 04:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:04
# Vrijeme opservacije (Unix timestamp): 1703304000
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 942.1 mb
# Pritisak na nivou mora: 1002 mb
# Brzina vjetra: 5.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 280 stepeni
# Kratki opis smijera vjetra: W
# Puni opis smijera vjetra: west
# Temperatura: 10 °C
# Aparentna temperatura: 10 °C
# Relativna vlaznost: 49 %
# Tacka rose: -0.3 °C
# Oblacnost: 44 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 3 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 97
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -24 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 04:08
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:04
# Vrijeme opservacije (Unix timestamp): 1703304503
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 942.1 mb
# Pritisak na nivou mora: 1002 mb
# Brzina vjetra: 5.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 280 stepeni
# Kratki opis smijera vjetra: W
# Puni opis smijera vjetra: west
# Temperatura: 10 °C
# Aparentna temperatura: 10 °C
# Relativna vlaznost: 49 %
# Tacka rose: -0.3 °C
# Oblacnost: 42 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 90
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -24 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['analysis', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 04:38
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:04
# Vrijeme opservacije (Unix timestamp): 1703306304
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 935 mb
# Pritisak na nivou mora: 1004.5 mb
# Brzina vjetra: 1.54 m/s
# Brzina vjetra (naleti): 3.6 m/s
# Smijer vetra: 252 stepeni
# Kratki opis smijera vjetra: WSW
# Puni opis smijera vjetra: west-southwest
# Temperatura: 5.3 °C
# Aparentna temperatura: 4.2 °C
# Relativna vlaznost: 85 %
# Tacka rose: 2.9 °C
# Oblacnost: 44 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 90
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -24 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['analysis', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 04:53
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:04
# Vrijeme opservacije (Unix timestamp): 1703307205
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 935 mb
# Pritisak na nivou mora: 1004.5 mb
# Brzina vjetra: 1.54 m/s
# Brzina vjetra (naleti): 3.6 m/s
# Smijer vetra: 252 stepeni
# Kratki opis smijera vjetra: WSW
# Puni opis smijera vjetra: west-southwest
# Temperatura: 5.3 °C
# Aparentna temperatura: 4.2 °C
# Relativna vlaznost: 85 %
# Tacka rose: 2.9 °C
# Oblacnost: 42 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 90
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -13.55 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['analysis', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 05:08
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:05
# Vrijeme opservacije (Unix timestamp): 1703308106
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 935 mb
# Pritisak na nivou mora: 1004.5 mb
# Brzina vjetra: 1.54 m/s
# Brzina vjetra (naleti): 3.6 m/s
# Smijer vetra: 252 stepeni
# Kratki opis smijera vjetra: WSW
# Puni opis smijera vjetra: west-southwest
# Temperatura: 5.3 °C
# Aparentna temperatura: 4.2 °C
# Relativna vlaznost: 85 %
# Tacka rose: 2.9 °C
# Oblacnost: 42 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 90
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -13.55 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['analysis', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 05:23
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:05
# Vrijeme opservacije (Unix timestamp): 1703309007
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 936 mb
# Pritisak na nivou mora: 1005.5 mb
# Brzina vjetra: 1.54 m/s
# Brzina vjetra (naleti): 3.6 m/s
# Smijer vetra: 268 stepeni
# Kratki opis smijera vjetra: W
# Puni opis smijera vjetra: west
# Temperatura: 5.8 °C
# Aparentna temperatura: 4.8 °C
# Relativna vlaznost: 82 %
# Tacka rose: 2.9 °C
# Oblacnost: 42 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 90
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -13.55 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 05:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:05
# Vrijeme opservacije (Unix timestamp): 1703309400
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 942.9 mb
# Pritisak na nivou mora: 1003 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 9 °C
# Aparentna temperatura: 9 °C
# Relativna vlaznost: 53 %
# Tacka rose: -0.1 °C
# Oblacnost: 42 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 1 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 76
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -13.55 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 05:38
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:05
# Vrijeme opservacije (Unix timestamp): 1703309909
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 942.9 mb
# Pritisak na nivou mora: 1003 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 9 °C
# Aparentna temperatura: 9 °C
# Relativna vlaznost: 53 %
# Tacka rose: -0.1 °C
# Oblacnost: 42 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 1 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 76
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -3.71 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 06:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:06
# Vrijeme opservacije (Unix timestamp): 1703311200
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 942.5 mb
# Pritisak na nivou mora: 1003 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 7 °C
# Aparentna temperatura: 5.7 °C
# Relativna vlaznost: 65 %
# Tacka rose: 0.9 °C
# Oblacnost: 42 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02d
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 1 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 76
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -3.71 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 06:08
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:06
# Vrijeme opservacije (Unix timestamp): 1703311710
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 942.5 mb
# Pritisak na nivou mora: 1003 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 7 °C
# Aparentna temperatura: 5.7 °C
# Relativna vlaznost: 65 %
# Tacka rose: 0.9 °C
# Oblacnost: 42 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02d
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 1 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 76
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -3.71 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 06:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:06
# Vrijeme opservacije (Unix timestamp): 1703313000
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 943.4 mb
# Pritisak na nivou mora: 1004 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 7 °C
# Aparentna temperatura: 5.7 °C
# Relativna vlaznost: 65 %
# Tacka rose: 0.9 °C
# Oblacnost: 44 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02d
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 1 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 76
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -3.71 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:17
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 06:38
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:06
# Vrijeme opservacije (Unix timestamp): 1703313512
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 943.4 mb
# Pritisak na nivou mora: 1004 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 7 °C
# Aparentna temperatura: 5.7 °C
# Relativna vlaznost: 65 %
# Tacka rose: 0.9 °C
# Oblacnost: 50 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02d
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 1 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0.82589203
# Indeks kvaliteta vazduha (AQI): 61
# Difuzno horizontalno suncevo zracenje: 36.55 W/m^2
# Direktno normalno suncevo zracenje: 319.84 W/m^2
# Globalno horizontalno suncevo zracenje: 55.96 W/m^2
# Procenjeno sunčevo zracenje: 51.7 W/m^2
# Solarni elevacioni ugao: 5.19 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 07:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:07
# Vrijeme opservacije (Unix timestamp): 1703314800
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 944.3 mb
# Pritisak na nivou mora: 1005 mb
# Brzina vjetra: 3.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 70 stepeni
# Kratki opis smijera vjetra: ENE
# Puni opis smijera vjetra: east-northeast
# Temperatura: 7 °C
# Aparentna temperatura: 4.9 °C
# Relativna vlaznost: 70 %
# Tacka rose: 1.9 °C
# Oblacnost: 42 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02d
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 1 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0.895494
# Indeks kvaliteta vazduha (AQI): 61
# Difuzno horizontalno suncevo zracenje: 36.55 W/m^2
# Direktno normalno suncevo zracenje: 319.84 W/m^2
# Globalno horizontalno suncevo zracenje: 55.96 W/m^2
# Procenjeno sunčevo zracenje: 53.6 W/m^2
# Solarni elevacioni ugao: 5.19 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -67.5 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 07:08
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:07
# Vrijeme opservacije (Unix timestamp): 1703315314
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 944.3 mb
# Pritisak na nivou mora: 1005 mb
# Brzina vjetra: 3.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 70 stepeni
# Kratki opis smijera vjetra: ENE
# Puni opis smijera vjetra: east-northeast
# Temperatura: 7 °C
# Aparentna temperatura: 4.9 °C
# Relativna vlaznost: 70 %
# Tacka rose: 1.9 °C
# Oblacnost: 42 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02d
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 5 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0.895494
# Indeks kvaliteta vazduha (AQI): 61
# Difuzno horizontalno suncevo zracenje: 36.55 W/m^2
# Direktno normalno suncevo zracenje: 319.84 W/m^2
# Globalno horizontalno suncevo zracenje: 55.96 W/m^2
# Procenjeno sunčevo zracenje: 53.6 W/m^2
# Solarni elevacioni ugao: 5.19 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -67.5 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 07:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:07
# Vrijeme opservacije (Unix timestamp): 1703316600
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 944.8 mb
# Pritisak na nivou mora: 1005 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 100 stepeni
# Kratki opis smijera vjetra: E
# Puni opis smijera vjetra: east
# Temperatura: 9 °C
# Aparentna temperatura: 9 °C
# Relativna vlaznost: 66 %
# Tacka rose: 3 °C
# Oblacnost: 50 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02d
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 5 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0.82589203
# Indeks kvaliteta vazduha (AQI): 61
# Difuzno horizontalno suncevo zracenje: 36.55 W/m^2
# Direktno normalno suncevo zracenje: 319.84 W/m^2
# Globalno horizontalno suncevo zracenje: 55.96 W/m^2
# Procenjeno sunčevo zracenje: 51.7 W/m^2
# Solarni elevacioni ugao: 5.19 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -67.5 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 07:38
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:07
# Vrijeme opservacije (Unix timestamp): 1703317116
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 944.8 mb
# Pritisak na nivou mora: 1005 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 100 stepeni
# Kratki opis smijera vjetra: E
# Puni opis smijera vjetra: east
# Temperatura: 9 °C
# Aparentna temperatura: 9 °C
# Relativna vlaznost: 66 %
# Tacka rose: 3 °C
# Oblacnost: 50 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02d
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 5 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0.91655755
# Indeks kvaliteta vazduha (AQI): 80
# Difuzno horizontalno suncevo zracenje: 62.42 W/m^2
# Direktno normalno suncevo zracenje: 570.82 W/m^2
# Globalno horizontalno suncevo zracenje: 180.46 W/m^2
# Procenjeno sunčevo zracenje: 166.8 W/m^2
# Solarni elevacioni ugao: 12.76 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -67.5 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 08:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:08
# Vrijeme opservacije (Unix timestamp): 1703318400
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 944.6 mb
# Pritisak na nivou mora: 1005 mb
# Brzina vjetra: 1.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 120 stepeni
# Kratki opis smijera vjetra: ESE
# Puni opis smijera vjetra: east-southeast
# Temperatura: 8 °C
# Aparentna temperatura: 8 °C
# Relativna vlaznost: 70 %
# Tacka rose: 2.9 °C
# Oblacnost: 50 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02d
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 5 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0.91655755
# Indeks kvaliteta vazduha (AQI): 78
# Difuzno horizontalno suncevo zracenje: 62.42 W/m^2
# Direktno normalno suncevo zracenje: 570.82 W/m^2
# Globalno horizontalno suncevo zracenje: 180.46 W/m^2
# Procenjeno sunčevo zracenje: 166.8 W/m^2
# Solarni elevacioni ugao: 12.76 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -45 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 08:08
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:08
# Vrijeme opservacije (Unix timestamp): 1703318918
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 944.6 mb
# Pritisak na nivou mora: 1005 mb
# Brzina vjetra: 1.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 120 stepeni
# Kratki opis smijera vjetra: ESE
# Puni opis smijera vjetra: east-southeast
# Temperatura: 8 °C
# Aparentna temperatura: 8 °C
# Relativna vlaznost: 70 %
# Tacka rose: 2.9 °C
# Oblacnost: 27 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02d
#    Kod: 801
#    Opis: Few clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.1386304
# Indeks kvaliteta vazduha (AQI): 78
# Difuzno horizontalno suncevo zracenje: 62.42 W/m^2
# Direktno normalno suncevo zracenje: 570.82 W/m^2
# Globalno horizontalno suncevo zracenje: 180.46 W/m^2
# Procenjeno sunčevo zracenje: 178.8 W/m^2
# Solarni elevacioni ugao: 12.76 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -45 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 08:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:08
# Vrijeme opservacije (Unix timestamp): 1703320200
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 945.9 mb
# Pritisak na nivou mora: 1006 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 10 °C
# Aparentna temperatura: 10 °C
# Relativna vlaznost: 66 %
# Tacka rose: 3.9 °C
# Oblacnost: 27 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02d
#    Kod: 801
#    Opis: Few clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.1386304
# Indeks kvaliteta vazduha (AQI): 78
# Difuzno horizontalno suncevo zracenje: 62.42 W/m^2
# Direktno normalno suncevo zracenje: 570.82 W/m^2
# Globalno horizontalno suncevo zracenje: 180.46 W/m^2
# Procenjeno sunčevo zracenje: 178.8 W/m^2
# Solarni elevacioni ugao: 12.76 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -45 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# ...
# Tacka rose: 3.8 °C
# Oblacnost: 87 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03n
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 156
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -60.17 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 21:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:21
# Vrijeme opservacije (Unix timestamp): 1703367000
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 948.5 mb
# Pritisak na nivou mora: 1009 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 9 °C
# Aparentna temperatura: 9 °C
# Relativna vlaznost: 70 %
# Tacka rose: 3.8 °C
# Oblacnost: 88 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03n
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 156
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -60.17 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 21:39
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:21
# Vrijeme opservacije (Unix timestamp): 1703367579
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 948.5 mb
# Pritisak na nivou mora: 1009 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 9 °C
# Aparentna temperatura: 9 °C
# Relativna vlaznost: 70 %
# Tacka rose: 3.8 °C
# Oblacnost: 88 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03n
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 155
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -67.49 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 22:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:22
# Vrijeme opservacije (Unix timestamp): 1703368800
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 949.5 mb
# Pritisak na nivou mora: 1010 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 9 °C
# Aparentna temperatura: 9 °C
# Relativna vlaznost: 70 %
# Tacka rose: 3.8 °C
# Oblacnost: 89 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03n
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 155
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -67.49 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 22:09
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:22
# Vrijeme opservacije (Unix timestamp): 1703369381
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 949.5 mb
# Pritisak na nivou mora: 1010 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 9 °C
# Aparentna temperatura: 9 °C
# Relativna vlaznost: 70 %
# Tacka rose: 3.8 °C
# Oblacnost: 88 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03n
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 155
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -67.49 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 22:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:22
# Vrijeme opservacije (Unix timestamp): 1703370600
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 949.3 mb
# Pritisak na nivou mora: 1010 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 120 stepeni
# Kratki opis smijera vjetra: ESE
# Puni opis smijera vjetra: east-southeast
# Temperatura: 8 °C
# Aparentna temperatura: 8 °C
# Relativna vlaznost: 75 %
# Tacka rose: 3.8 °C
# Oblacnost: 88 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03n
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 155
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -67.49 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 22:39
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:22
# Vrijeme opservacije (Unix timestamp): 1703371182
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 949.3 mb
# Pritisak na nivou mora: 1010 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 120 stepeni
# Kratki opis smijera vjetra: ESE
# Puni opis smijera vjetra: east-southeast
# Temperatura: 8 °C
# Aparentna temperatura: 8 °C
# Relativna vlaznost: 75 %
# Tacka rose: 3.8 °C
# Oblacnost: 88 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03n
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 155
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -69.39 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 23:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:23
# Vrijeme opservacije (Unix timestamp): 1703372400
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 949 mb
# Pritisak na nivou mora: 1010 mb
# Brzina vjetra: 1.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 140 stepeni
# Kratki opis smijera vjetra: SE
# Puni opis smijera vjetra: southeast
# Temperatura: 7 °C
# Aparentna temperatura: 6.3 °C
# Relativna vlaznost: 81 %
# Tacka rose: 4 °C
# Oblacnost: 87 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03n
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 155
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -69.39 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 23:09
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:23
# Vrijeme opservacije (Unix timestamp): 1703372985
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 949 mb
# Pritisak na nivou mora: 1010 mb
# Brzina vjetra: 1.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 140 stepeni
# Kratki opis smijera vjetra: SE
# Puni opis smijera vjetra: southeast
# Temperatura: 7 °C
# Aparentna temperatura: 6.3 °C
# Relativna vlaznost: 81 %
# Tacka rose: 4 °C
# Oblacnost: 87 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03n
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 155
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -69.39 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 23:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:23
# Vrijeme opservacije (Unix timestamp): 1703374200
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 949 mb
# Pritisak na nivou mora: 1010 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 7 °C
# Aparentna temperatura: 8.1 °C
# Relativna vlaznost: 81 %
# Tacka rose: 4 °C
# Oblacnost: 88 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03n
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 155
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -69.39 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-23 23:39
# Posljednji vremenski ciklus (zastarijelo): 2023-12-23:23
# Vrijeme opservacije (Unix timestamp): 1703374787
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 949 mb
# Pritisak na nivou mora: 1010 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 7 °C
# Aparentna temperatura: 8.1 °C
# Relativna vlaznost: 81 %
# Tacka rose: 4 °C
# Oblacnost: 88 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03n
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 156
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -64.58 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 00:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:00
# Vrijeme opservacije (Unix timestamp): 1703376000
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 950 mb
# Pritisak na nivou mora: 1011 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 7 °C
# Aparentna temperatura: 8.1 °C
# Relativna vlaznost: 87 %
# Tacka rose: 5 °C
# Oblacnost: 88 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03n
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 156
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -64.58 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Broj opservacija: None
# Geografska širina: 43.84864
# Geografska duzna: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 00:09
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:00
# Vrijeme opservacije (Unix timestamp): 1703376590
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod države: 01
# Pritisak: 950 mb
# Pritisak na nivou mora: 1011 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 7 °C
# Aparentna temperatura: 8.1 °C
# Relativna vlaznost: 87 %
# Tacka rose: 5 °C
# Oblacnost: 89 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03n
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 156
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno suncevo zracenje: 0 W/m^2
# Globalno horizontalno suncevo zracenje: 0 W/m^2
# Procenjeno sunčevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -64.58 stepeni
# Solarni satni ugao (solarno podne) (zastarjelo): -90 stepeni
#
# ----------------------------------------
