# %%
import requests
from datetime import datetime, timedelta
import time
import csv

def get_energy_data(api_key, city='Sarajevo', country='BA'):
    api_url = 'https://api.weatherbit.io/v2.0/current'

    current_datetime = datetime.now()
    current_day_start = datetime(current_datetime.year, current_datetime.month, current_datetime.day, 0, 0, 0)

    params = {
        'city': city,
        'country': country,
        'key': api_key,
        #'lang': 'bs', ispisivalo mi je error
    }

    try:
        response = requests.get(api_url, params=params)

        if response.status_code == 200:
            data = response.json()

            # Otvori CSV fajl za pisanje
            with open('energy_data_zadnja_verzija.csv', mode='a', newline='') as csv_file:
                fieldnames = ['Time'] + list(data['data'][0].keys())
                writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

                 # Ako je fajl prazan, napiši zaglavlje
                if csv_file.tell() == 0:
                    writer.writeheader()

                # Provjeri da li se promjenio datum
                if current_datetime.date() != current_day_start.date():
                    print(f"Novi dan! ")
                    # Update current_day_start
                    current_day_start = datetime(current_datetime.year, current_datetime.month, current_datetime.day, 0, 0, 0)

                for entry in data['data']:
                    # Dinamičko postavljanje vremena na trenutno vrijeme
                    time_str = datetime.now().strftime('%H:%M:%S')
                    entry['Time'] = time_str
                     # Dodaje red u CSV fajl
                    writer.writerow(entry)

                    # Printa poruku prije svakog mjerenja
                    print(f"Mjerenje za {datetime.now().date()} u {datetime.now().strftime('%H:%M:%S')}.")

                   # Isprintaj sve parametre za svaku opservaciju
                    print(f"Broj opservacija: {entry.get('count')}")
                    print(f"Geografska sirina: {entry.get('lat')}")
                    print(f"Geografska duzina: {entry.get('lon')}")
                    print(f"Vrijeme izlaska sunca (UTC): {entry.get('sunrise')}")
                    print(f"Vrijeme zalaska sunca (UTC): {entry.get('sunset')}")
                    print(f"Vremenska zona: {entry.get('timezone')}")
                    print(f"ID stanice (zastarijelo): {entry.get('station')}")
                    print(f"Izvori podataka: {entry.get('sources')}")
                    print(f"Vrijeme posljednje opservacije: {entry.get('ob_time')}")
                    print(f"Posljednji vremenski ciklus (zastarijelo): {entry.get('datetime')}")
                    print(f"Vrijeme opservacije (Unix timestamp): {entry.get('ts')}")
                    print(f"Naziv grada: {entry.get('city_name')}")
                    print(f"Kod zemlje: {entry.get('country_code')}")
                    print(f"Kod drzave: {entry.get('state_code')}")
                    print(f"Pritisak: {entry.get('pres')} mb")
                    print(f"Pritisak na nivou mora: {entry.get('slp')} mb")
                    print(f"Brzina vjetra: {entry.get('wind_spd')} m/s")
                    print(f"Brzina vjetra (naleti): {entry.get('gust')} m/s")
                    print(f"Smijer vetra: {entry.get('wind_dir')} stepeni")
                    print(f"Kratki opis smijera vjetra: {entry.get('wind_cdir')}")
                    print(f"Puni opis smijera vjetra: {entry.get('wind_cdir_full')}")
                    print(f"Temperatura: {entry.get('temp')} °C")
                    print(f"Aparentna temperatura: {entry.get('app_temp')} °C")
                    print(f"Relativna vlaznost: {entry.get('rh')} %")
                    print(f"Tacka rose: {entry.get('dewpt')} °C")
                    print(f"Oblacnost: {entry.get('clouds')} %")
                    print(f"Dio dana: {entry.get('pod')} (d = dan / n = noć)")
                    print("Vremenski uslovi:")
                    print(f"   Ikona: {entry['weather'].get('icon')}")
                    print(f"   Kod: {entry['weather'].get('code')}")
                    print(f"   Opis: {entry['weather'].get('description')}")
                    print(f"Vidljivost: {entry.get('vis')} km")
                    print(f"Padavine: {entry.get('precip')} mm/h")
                    print(f"Snijeg: {entry.get('snow')} mm/h")
                    print(f"UV indeks: {entry.get('uv')}")
                    print(f"Indeks kvaliteta vazduha (AQI): {entry.get('aqi')}")
                    print(f"Difuzno horizontalno suncevo zracenje: {entry.get('dhi')} W/m^2")
                    print(f"Direktno normalno sunčevo zracenje: {entry.get('dni')} W/m^2")
                    print(f"Globalno horizontalno sunčevo zracenje: {entry.get('ghi')} W/m^2")
                    print(f"Procenjeno suncevo zracenje: {entry.get('solar_rad')} W/m^2")
                    print(f"Solarni elevacioni ugao: {entry.get('elev_angle')} stepeni")
                    print(f"Solarni satni ugao (zastarjelo): {entry.get('h_angle')} stepeni")

                    print("\n" + "-"*40 + "\n")

        else:
            print(f'Error {response.status_code}: {response.text}')

    except Exception as e:
        print(f'Error: {e}')

def parse_datetime(dt_str):
    try:
        return datetime.strptime(dt_str, '%Y-%m-%d %H:%M:%S')
    except ValueError:
        return datetime.min

# Postavljanje periodičnog zadatka
while True:
    get_energy_data(api_key='abd79c512df344da80c500911fd874fe')
    time.sleep(900)  # Pauza od 900 sekundi (15 minuta) prije sljedećeg poziva
# Out:
# Mjerenje za 2023-12-24 u 10:45:11.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 09:12
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:09
# Vrijeme opservacije (Unix timestamp): 1703409133
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953 mb
# Pritisak na nivou mora: 1014 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 8 °C
# Aparentna temperatura: 8 °C
# Relativna vlaznost: 81 %
# Tacka rose: 4.9 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.6727979
# Indeks kvaliteta vazduha (AQI): 91
# Difuzno horizontalno suncevo zracenje: 76.13 W/m^2
# Direktno normalno sunčevo zracenje: 679.96 W/m^2
# Globalno horizontalno sunčevo zracenje: 284.59 W/m^2
# Procenjeno suncevo zracenje: 284.6 W/m^2
# Solarni elevacioni ugao: 18.48 stepeni
# Solarni satni ugao (zastarjelo): -22.5 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 11:00:11.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 09:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:09
# Vrijeme opservacije (Unix timestamp): 1703410212
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.4 mb
# Pritisak na nivou mora: 1014 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 10 °C
# Aparentna temperatura: 10 °C
# Relativna vlaznost: 71 %
# Tacka rose: 5 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.9255682
# Indeks kvaliteta vazduha (AQI): 91
# Difuzno horizontalno suncevo zracenje: 82.99 W/m^2
# Direktno normalno sunčevo zracenje: 729.13 W/m^2
# Globalno horizontalno sunčevo zracenje: 348.62 W/m^2
# Procenjeno suncevo zracenje: 348.6 W/m^2
# Solarni elevacioni ugao: 21.93 stepeni
# Solarni satni ugao (zastarjelo): -22.5 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 11:15:13.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 09:45
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:09
# Vrijeme opservacije (Unix timestamp): 1703411113
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.4 mb
# Pritisak na nivou mora: 1014 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 10 °C
# Aparentna temperatura: 10 °C
# Relativna vlaznost: 71 %
# Tacka rose: 5 °C
# Oblacnost: 8 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.8192769
# Indeks kvaliteta vazduha (AQI): 91
# Difuzno horizontalno suncevo zracenje: 82.99 W/m^2
# Direktno normalno sunčevo zracenje: 729.13 W/m^2
# Globalno horizontalno sunčevo zracenje: 348.62 W/m^2
# Procenjeno suncevo zracenje: 348.6 W/m^2
# Solarni elevacioni ugao: 21.93 stepeni
# Solarni satni ugao (zastarjelo): -22.5 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 11:30:14.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 10:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:10
# Vrijeme opservacije (Unix timestamp): 1703412014
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.4 mb
# Pritisak na nivou mora: 1014 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 10 °C
# Aparentna temperatura: 10 °C
# Relativna vlaznost: 71 %
# Tacka rose: 5 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.9255682
# Indeks kvaliteta vazduha (AQI): 93
# Difuzno horizontalno suncevo zracenje: 82.99 W/m^2
# Direktno normalno sunčevo zracenje: 729.13 W/m^2
# Globalno horizontalno sunčevo zracenje: 348.62 W/m^2
# Procenjeno suncevo zracenje: 348.6 W/m^2
# Solarni elevacioni ugao: 21.93 stepeni
# Solarni satni ugao (zastarjelo): 0 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 11:45:14.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 10:13
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:10
# Vrijeme opservacije (Unix timestamp): 1703412799
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.4 mb
# Pritisak na nivou mora: 1014 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 10 °C
# Aparentna temperatura: 10 °C
# Relativna vlaznost: 71 %
# Tacka rose: 5 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.9255682
# Indeks kvaliteta vazduha (AQI): 93
# Difuzno horizontalno suncevo zracenje: 82.99 W/m^2
# Direktno normalno sunčevo zracenje: 729.13 W/m^2
# Globalno horizontalno sunčevo zracenje: 348.62 W/m^2
# Procenjeno suncevo zracenje: 348.6 W/m^2
# Solarni elevacioni ugao: 21.93 stepeni
# Solarni satni ugao (zastarjelo): 0 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 12:00:15.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 10:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:10
# Vrijeme opservacije (Unix timestamp): 1703413816
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.8 mb
# Pritisak na nivou mora: 1014 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 12 °C
# Aparentna temperatura: 12 °C
# Relativna vlaznost: 62 %
# Tacka rose: 4.9 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.991493
# Indeks kvaliteta vazduha (AQI): 98
# Difuzno horizontalno suncevo zracenje: 84.4 W/m^2
# Direktno normalno sunčevo zracenje: 738.84 W/m^2
# Globalno horizontalno sunčevo zracenje: 362.87 W/m^2
# Procenjeno suncevo zracenje: 362.9 W/m^2
# Solarni elevacioni ugao: 22.7 stepeni
# Solarni satni ugao (zastarjelo): 0 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 12:15:16.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 10:45
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:10
# Vrijeme opservacije (Unix timestamp): 1703414717
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.8 mb
# Pritisak na nivou mora: 1014 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 12 °C
# Aparentna temperatura: 12 °C
# Relativna vlaznost: 62 %
# Tacka rose: 4.9 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.991493
# Indeks kvaliteta vazduha (AQI): 98
# Difuzno horizontalno suncevo zracenje: 84.4 W/m^2
# Direktno normalno sunčevo zracenje: 738.84 W/m^2
# Globalno horizontalno sunčevo zracenje: 362.87 W/m^2
# Procenjeno suncevo zracenje: 362.9 W/m^2
# Solarni elevacioni ugao: 22.7 stepeni
# Solarni satni ugao (zastarjelo): 0 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 12:30:17.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 11:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:11
# Vrijeme opservacije (Unix timestamp): 1703415618
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 954 mb
# Pritisak na nivou mora: 1014 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 13 °C
# Aparentna temperatura: 13 °C
# Relativna vlaznost: 58 %
# Tacka rose: 4.9 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.991493
# Indeks kvaliteta vazduha (AQI): 98
# Difuzno horizontalno suncevo zracenje: 84.4 W/m^2
# Direktno normalno sunčevo zracenje: 738.84 W/m^2
# Globalno horizontalno sunčevo zracenje: 362.87 W/m^2
# Procenjeno suncevo zracenje: 362.9 W/m^2
# Solarni elevacioni ugao: 22.7 stepeni
# Solarni satni ugao (zastarjelo): 22.5 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 12:45:18.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 11:15
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:11
# Vrijeme opservacije (Unix timestamp): 1703416519
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 954 mb
# Pritisak na nivou mora: 1014 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 13 °C
# Aparentna temperatura: 13 °C
# Relativna vlaznost: 58 %
# Tacka rose: 4.9 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.991493
# Indeks kvaliteta vazduha (AQI): 98
# Difuzno horizontalno suncevo zracenje: 84.4 W/m^2
# Direktno normalno sunčevo zracenje: 738.84 W/m^2
# Globalno horizontalno sunčevo zracenje: 362.87 W/m^2
# Procenjeno suncevo zracenje: 362.9 W/m^2
# Solarni elevacioni ugao: 22.7 stepeni
# Solarni satni ugao (zastarjelo): 22.5 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 13:00:19.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 11:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:11
# Vrijeme opservacije (Unix timestamp): 1703417420
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 954.2 mb
# Pritisak na nivou mora: 1014 mb
# Brzina vjetra: 1.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 160 stepeni
# Kratki opis smijera vjetra: SSE
# Puni opis smijera vjetra: south-southeast
# Temperatura: 14 °C
# Aparentna temperatura: 14 °C
# Relativna vlaznost: 54 %
# Tacka rose: 4.8 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.8265488
# Indeks kvaliteta vazduha (AQI): 100
# Difuzno horizontalno suncevo zracenje: 80.62 W/m^2
# Direktno normalno sunčevo zracenje: 712.51 W/m^2
# Globalno horizontalno sunčevo zracenje: 325.51 W/m^2
# Procenjeno suncevo zracenje: 325.5 W/m^2
# Solarni elevacioni ugao: 20.69 stepeni
# Solarni satni ugao (zastarjelo): 22.5 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 13:15:20.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 11:45
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:11
# Vrijeme opservacije (Unix timestamp): 1703418321
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 954.2 mb
# Pritisak na nivou mora: 1014 mb
# Brzina vjetra: 1.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 160 stepeni
# Kratki opis smijera vjetra: SSE
# Puni opis smijera vjetra: south-southeast
# Temperatura: 14 °C
# Aparentna temperatura: 14 °C
# Relativna vlaznost: 54 %
# Tacka rose: 4.8 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.8265488
# Indeks kvaliteta vazduha (AQI): 100
# Difuzno horizontalno suncevo zracenje: 80.62 W/m^2
# Direktno normalno sunčevo zracenje: 712.51 W/m^2
# Globalno horizontalno sunčevo zracenje: 325.51 W/m^2
# Procenjeno suncevo zracenje: 325.5 W/m^2
# Solarni elevacioni ugao: 20.69 stepeni
# Solarni satni ugao (zastarjelo): 22.5 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 13:30:21.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 12:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:12
# Vrijeme opservacije (Unix timestamp): 1703419222
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.3 mb
# Pritisak na nivou mora: 1013 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 14 °C
# Aparentna temperatura: 14 °C
# Relativna vlaznost: 54 %
# Tacka rose: 4.8 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.8265488
# Indeks kvaliteta vazduha (AQI): 100
# Difuzno horizontalno suncevo zracenje: 80.62 W/m^2
# Direktno normalno sunčevo zracenje: 712.51 W/m^2
# Globalno horizontalno sunčevo zracenje: 325.51 W/m^2
# Procenjeno suncevo zracenje: 325.5 W/m^2
# Solarni elevacioni ugao: 20.69 stepeni
# Solarni satni ugao (zastarjelo): 45 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 13:45:22.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 12:15
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:12
# Vrijeme opservacije (Unix timestamp): 1703420123
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.3 mb
# Pritisak na nivou mora: 1013 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 14 °C
# Aparentna temperatura: 14 °C
# Relativna vlaznost: 54 %
# Tacka rose: 4.8 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.8265488
# Indeks kvaliteta vazduha (AQI): 100
# Difuzno horizontalno suncevo zracenje: 80.62 W/m^2
# Direktno normalno sunčevo zracenje: 712.51 W/m^2
# Globalno horizontalno sunčevo zracenje: 325.51 W/m^2
# Procenjeno suncevo zracenje: 325.5 W/m^2
# Solarni elevacioni ugao: 20.69 stepeni
# Solarni satni ugao (zastarjelo): 45 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 14:00:23.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 12:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:12
# Vrijeme opservacije (Unix timestamp): 1703421024
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.5 mb
# Pritisak na nivou mora: 1013 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 15 °C
# Aparentna temperatura: 15 °C
# Relativna vlaznost: 47 %
# Tacka rose: 3.8 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.539705
# Indeks kvaliteta vazduha (AQI): 95
# Difuzno horizontalno suncevo zracenje: 70.92 W/m^2
# Direktno normalno sunčevo zracenje: 640.27 W/m^2
# Globalno horizontalno sunčevo zracenje: 241.44 W/m^2
# Procenjeno suncevo zracenje: 241.4 W/m^2
# Solarni elevacioni ugao: 16.13 stepeni
# Solarni satni ugao (zastarjelo): 45 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 14:15:24.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 13:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:13
# Vrijeme opservacije (Unix timestamp): 1703422800
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.7 mb
# Pritisak na nivou mora: 1013 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 16 °C
# Aparentna temperatura: 16 °C
# Relativna vlaznost: 48 %
# Tacka rose: 5 °C
# Oblacnost: 25 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02d
#    Kod: 801
#    Opis: Few clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.2741059
# Indeks kvaliteta vazduha (AQI): 95
# Difuzno horizontalno suncevo zracenje: 70.92 W/m^2
# Direktno normalno sunčevo zracenje: 640.27 W/m^2
# Globalno horizontalno sunčevo zracenje: 241.44 W/m^2
# Procenjeno suncevo zracenje: 239.7 W/m^2
# Solarni elevacioni ugao: 16.13 stepeni
# Solarni satni ugao (zastarjelo): 67.5 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 14:30:25.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 13:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:13
# Vrijeme opservacije (Unix timestamp): 1703422826
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.7 mb
# Pritisak na nivou mora: 1013 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 16 °C
# Aparentna temperatura: 16 °C
# Relativna vlaznost: 48 %
# Tacka rose: 5 °C
# Oblacnost: 71 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03d
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0.78540355
# Indeks kvaliteta vazduha (AQI): 95
# Difuzno horizontalno suncevo zracenje: 70.92 W/m^2
# Direktno normalno sunčevo zracenje: 640.27 W/m^2
# Globalno horizontalno sunčevo zracenje: 241.44 W/m^2
# Procenjeno suncevo zracenje: 181.2 W/m^2
# Solarni elevacioni ugao: 16.13 stepeni
# Solarni satni ugao (zastarjelo): 67.5 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 14:45:27.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 13:15
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:13
# Vrijeme opservacije (Unix timestamp): 1703423728
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.7 mb
# Pritisak na nivou mora: 1013 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 16 °C
# Aparentna temperatura: 16 °C
# Relativna vlaznost: 48 %
# Tacka rose: 5 °C
# Oblacnost: 71 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03d
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0.78540355
# Indeks kvaliteta vazduha (AQI): 95
# Difuzno horizontalno suncevo zracenje: 70.92 W/m^2
# Direktno normalno sunčevo zracenje: 640.27 W/m^2
# Globalno horizontalno sunčevo zracenje: 241.44 W/m^2
# Procenjeno suncevo zracenje: 181.2 W/m^2
# Solarni elevacioni ugao: 16.13 stepeni
# Solarni satni ugao (zastarjelo): 67.5 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 15:00:28.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 13:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:13
# Vrijeme opservacije (Unix timestamp): 1703424629
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.7 mb
# Pritisak na nivou mora: 1013 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 16 °C
# Aparentna temperatura: 16 °C
# Relativna vlaznost: 44 %
# Tacka rose: 3.7 °C
# Oblacnost: 71 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03d
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0.6701761
# Indeks kvaliteta vazduha (AQI): 91
# Difuzno horizontalno suncevo zracenje: 52.75 W/m^2
# Direktno normalno sunčevo zracenje: 484.06 W/m^2
# Globalno horizontalno sunčevo zracenje: 123.84 W/m^2
# Procenjeno suncevo zracenje: 92.9 W/m^2
# Solarni elevacioni ugao: 9.49 stepeni
# Solarni satni ugao (zastarjelo): 67.5 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 15:15:29.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 13:45
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:13
# Vrijeme opservacije (Unix timestamp): 1703425530
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.7 mb
# Pritisak na nivou mora: 1013 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 16 °C
# Aparentna temperatura: 16 °C
# Relativna vlaznost: 44 %
# Tacka rose: 3.7 °C
# Oblacnost: 71 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03d
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0.6701761
# Indeks kvaliteta vazduha (AQI): 91
# Difuzno horizontalno suncevo zracenje: 52.75 W/m^2
# Direktno normalno sunčevo zracenje: 484.06 W/m^2
# Globalno horizontalno sunčevo zracenje: 123.84 W/m^2
# Procenjeno suncevo zracenje: 92.9 W/m^2
# Solarni elevacioni ugao: 9.49 stepeni
# Solarni satni ugao (zastarjelo): 67.5 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 15:30:30.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 14:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:14
# Vrijeme opservacije (Unix timestamp): 1703426431
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.3 mb
# Pritisak na nivou mora: 1013 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 220 stepeni
# Kratki opis smijera vjetra: SW
# Puni opis smijera vjetra: southwest
# Temperatura: 14 °C
# Aparentna temperatura: 14 °C
# Relativna vlaznost: 50 %
# Tacka rose: 3.7 °C
# Oblacnost: 63 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02d
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0.74269855
# Indeks kvaliteta vazduha (AQI): 91
# Difuzno horizontalno suncevo zracenje: 52.75 W/m^2
# Direktno normalno sunčevo zracenje: 484.06 W/m^2
# Globalno horizontalno sunčevo zracenje: 123.84 W/m^2
# Procenjeno suncevo zracenje: 103.2 W/m^2
# Solarni elevacioni ugao: 9.49 stepeni
# Solarni satni ugao (zastarjelo): 90 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 15:45:31.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 14:15
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:14
# Vrijeme opservacije (Unix timestamp): 1703427332
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.3 mb
# Pritisak na nivou mora: 1013 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 220 stepeni
# Kratki opis smijera vjetra: SW
# Puni opis smijera vjetra: southwest
# Temperatura: 14 °C
# Aparentna temperatura: 14 °C
# Relativna vlaznost: 50 %
# Tacka rose: 3.7 °C
# Oblacnost: 63 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02d
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0.74269855
# Indeks kvaliteta vazduha (AQI): 91
# Difuzno horizontalno suncevo zracenje: 52.75 W/m^2
# Direktno normalno sunčevo zracenje: 484.06 W/m^2
# Globalno horizontalno sunčevo zracenje: 123.84 W/m^2
# Procenjeno suncevo zracenje: 103.2 W/m^2
# Solarni elevacioni ugao: 9.49 stepeni
# Solarni satni ugao (zastarjelo): 90 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 16:00:32.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 14:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:14
# Vrijeme opservacije (Unix timestamp): 1703428233
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 952.9 mb
# Pritisak na nivou mora: 1013 mb
# Brzina vjetra: 1.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 230 stepeni
# Kratki opis smijera vjetra: SW
# Puni opis smijera vjetra: southwest
# Temperatura: 12 °C
# Aparentna temperatura: 12 °C
# Relativna vlaznost: 62 %
# Tacka rose: 4.9 °C
# Oblacnost: 63 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02d
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0.70671934
# Indeks kvaliteta vazduha (AQI): 91
# Difuzno horizontalno suncevo zracenje: 14.79 W/m^2
# Direktno normalno sunčevo zracenje: 80.06 W/m^2
# Globalno horizontalno sunčevo zracenje: 8.58 W/m^2
# Procenjeno suncevo zracenje: 7.2 W/m^2
# Solarni elevacioni ugao: 1.25 stepeni
# Solarni satni ugao (zastarjelo): 90 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 16:15:33.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 14:45
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:14
# Vrijeme opservacije (Unix timestamp): 1703429134
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 952.9 mb
# Pritisak na nivou mora: 1013 mb
# Brzina vjetra: 1.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 230 stepeni
# Kratki opis smijera vjetra: SW
# Puni opis smijera vjetra: southwest
# Temperatura: 12 °C
# Aparentna temperatura: 12 °C
# Relativna vlaznost: 62 %
# Tacka rose: 4.9 °C
# Oblacnost: 63 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0.70671934
# Indeks kvaliteta vazduha (AQI): 82
# Difuzno horizontalno suncevo zracenje: 14.79 W/m^2
# Direktno normalno sunčevo zracenje: 80.06 W/m^2
# Globalno horizontalno sunčevo zracenje: 8.58 W/m^2
# Procenjeno suncevo zracenje: 7.2 W/m^2
# Solarni elevacioni ugao: 1.25 stepeni
# Solarni satni ugao (zastarjelo): 90 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 16:30:34.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 15:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:15
# Vrijeme opservacije (Unix timestamp): 1703430035
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.4 mb
# Pritisak na nivou mora: 1014 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 120 stepeni
# Kratki opis smijera vjetra: ESE
# Puni opis smijera vjetra: east-southeast
# Temperatura: 10 °C
# Aparentna temperatura: 10 °C
# Relativna vlaznost: 66 %
# Tacka rose: 3.9 °C
# Oblacnost: 73 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03n
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0.6204578
# Indeks kvaliteta vazduha (AQI): 82
# Difuzno horizontalno suncevo zracenje: 14.79 W/m^2
# Direktno normalno sunčevo zracenje: 80.06 W/m^2
# Globalno horizontalno sunčevo zracenje: 8.58 W/m^2
# Procenjeno suncevo zracenje: 6.2 W/m^2
# Solarni elevacioni ugao: 1.25 stepeni
# Solarni satni ugao (zastarjelo): 81 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 16:45:36.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 15:15
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:15
# Vrijeme opservacije (Unix timestamp): 1703430936
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.4 mb
# Pritisak na nivou mora: 1014 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 120 stepeni
# Kratki opis smijera vjetra: ESE
# Puni opis smijera vjetra: east-southeast
# Temperatura: 10 °C
# Aparentna temperatura: 10 °C
# Relativna vlaznost: 66 %
# Tacka rose: 3.9 °C
# Oblacnost: 73 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03n
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0.6204578
# Indeks kvaliteta vazduha (AQI): 82
# Difuzno horizontalno suncevo zracenje: 14.79 W/m^2
# Direktno normalno sunčevo zracenje: 80.06 W/m^2
# Globalno horizontalno sunčevo zracenje: 8.58 W/m^2
# Procenjeno suncevo zracenje: 6.2 W/m^2
# Solarni elevacioni ugao: 1.25 stepeni
# Solarni satni ugao (zastarjelo): 81 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 17:00:37.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 15:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:15
# Vrijeme opservacije (Unix timestamp): 1703431837
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.2 mb
# Pritisak na nivou mora: 1014 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 9 °C
# Aparentna temperatura: 9 °C
# Relativna vlaznost: 70 %
# Tacka rose: 3.8 °C
# Oblacnost: 73 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03n
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 78
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno sunčevo zracenje: 0 W/m^2
# Globalno horizontalno sunčevo zracenje: 0 W/m^2
# Procenjeno suncevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -8.13 stepeni
# Solarni satni ugao (zastarjelo): 81 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 17:15:38.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:13
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 15:45
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:15
# Vrijeme opservacije (Unix timestamp): 1703432738
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.2 mb
# Pritisak na nivou mora: 1014 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 9 °C
# Aparentna temperatura: 9 °C
# Relativna vlaznost: 70 %
# Tacka rose: 3.8 °C
# Oblacnost: 72 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03n
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 78
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno sunčevo zracenje: 0 W/m^2
# Globalno horizontalno sunčevo zracenje: 0 W/m^2
# Procenjeno suncevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -8.13 stepeni
# Solarni satni ugao (zastarjelo): 81 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 17:30:39.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 16:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:16
# Vrijeme opservacije (Unix timestamp): 1703433639
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953 mb
# Pritisak na nivou mora: 1014 mb
# Brzina vjetra: 1.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 130 stepeni
# Kratki opis smijera vjetra: SE
# Puni opis smijera vjetra: southeast
# Temperatura: 8 °C
# Aparentna temperatura: 8 °C
# Relativna vlaznost: 81 %
# Tacka rose: 4.9 °C
# Oblacnost: 42 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 1 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 78
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno sunčevo zracenje: 0 W/m^2
# Globalno horizontalno sunčevo zracenje: 0 W/m^2
# Procenjeno suncevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -8.13 stepeni
# Solarni satni ugao (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 17:45:40.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 16:15
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:16
# Vrijeme opservacije (Unix timestamp): 1703434540
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953 mb
# Pritisak na nivou mora: 1014 mb
# Brzina vjetra: 1.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 130 stepeni
# Kratki opis smijera vjetra: SE
# Puni opis smijera vjetra: southeast
# Temperatura: 8 °C
# Aparentna temperatura: 8 °C
# Relativna vlaznost: 81 %
# Tacka rose: 4.9 °C
# Oblacnost: 42 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 1 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 78
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno sunčevo zracenje: 0 W/m^2
# Globalno horizontalno sunčevo zracenje: 0 W/m^2
# Procenjeno suncevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -8.13 stepeni
# Solarni satni ugao (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 18:00:41.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 16:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:16
# Vrijeme opservacije (Unix timestamp): 1703435441
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 952.8 mb
# Pritisak na nivou mora: 1014 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 7 °C
# Aparentna temperatura: 8.1 °C
# Relativna vlaznost: 81 %
# Tacka rose: 4 °C
# Oblacnost: 40 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 801
#    Opis: Few clouds
# Vidljivost: 1 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 72
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno sunčevo zracenje: 0 W/m^2
# Globalno horizontalno sunčevo zracenje: 0 W/m^2
# Procenjeno suncevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -18.29 stepeni
# Solarni satni ugao (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 18:15:42.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 16:45
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:16
# Vrijeme opservacije (Unix timestamp): 1703436342
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 952.8 mb
# Pritisak na nivou mora: 1014 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 7 °C
# Aparentna temperatura: 8.1 °C
# Relativna vlaznost: 81 %
# Tacka rose: 4 °C
# Oblacnost: 73 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03n
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 1 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 72
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno sunčevo zracenje: 0 W/m^2
# Globalno horizontalno sunčevo zracenje: 0 W/m^2
# Procenjeno suncevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -18.29 stepeni
# Solarni satni ugao (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 18:30:42.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 17:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:17
# Vrijeme opservacije (Unix timestamp): 1703437243
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.5 mb
# Pritisak na nivou mora: 1015 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 6 °C
# Aparentna temperatura: 5.9 °C
# Relativna vlaznost: 93 %
# Tacka rose: 5 °C
# Oblacnost: 40 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 801
#    Opis: Few clouds
# Vidljivost: 0 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 72
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno sunčevo zracenje: 0 W/m^2
# Globalno horizontalno sunčevo zracenje: 0 W/m^2
# Procenjeno suncevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -18.29 stepeni
# Solarni satni ugao (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 18:45:44.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 17:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:17
# Vrijeme opservacije (Unix timestamp): 1703439000
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.3 mb
# Pritisak na nivou mora: 1015 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 5 °C
# Aparentna temperatura: 6 °C
# Relativna vlaznost: 93 %
# Tacka rose: 4 °C
# Oblacnost: 47 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 0 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 104
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno sunčevo zracenje: 0 W/m^2
# Globalno horizontalno sunčevo zracenje: 0 W/m^2
# Procenjeno suncevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -18.29 stepeni
# Solarni satni ugao (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 19:00:45.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 17:30
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:17
# Vrijeme opservacije (Unix timestamp): 1703439000
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.3 mb
# Pritisak na nivou mora: 1015 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 5 °C
# Aparentna temperatura: 6 °C
# Relativna vlaznost: 93 %
# Tacka rose: 4 °C
# Oblacnost: 47 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 802
#    Opis: Scattered clouds
# Vidljivost: 0 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 104
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno sunčevo zracenje: 0 W/m^2
# Globalno horizontalno sunčevo zracenje: 0 W/m^2
# Procenjeno suncevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -18.29 stepeni
# Solarni satni ugao (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 19:15:46.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 18:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:18
# Vrijeme opservacije (Unix timestamp): 1703440800
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.3 mb
# Pritisak na nivou mora: 1015 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 5 °C
# Aparentna temperatura: 4.8 °C
# Relativna vlaznost: 93 %
# Tacka rose: 4 °C
# Oblacnost: 40 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c02n
#    Kod: 801
#    Opis: Few clouds
# Vidljivost: 1 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 131
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno sunčevo zracenje: 0 W/m^2
# Globalno horizontalno sunčevo zracenje: 0 W/m^2
# Procenjeno suncevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -28.91 stepeni
# Solarni satni ugao (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 19:30:47.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 18:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:18
# Vrijeme opservacije (Unix timestamp): 1703440800
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 953.3 mb
# Pritisak na nivou mora: 1015 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 5 °C
# Aparentna temperatura: 4.8 °C
# Relativna vlaznost: 93 %
# Tacka rose: 4 °C
# Oblacnost: 71 %
# Dio dana: n (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c03n
#    Kod: 803
#    Opis: Broken clouds
# Vidljivost: 1 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 0
# Indeks kvaliteta vazduha (AQI): 131
# Difuzno horizontalno suncevo zracenje: 0 W/m^2
# Direktno normalno sunčevo zracenje: 0 W/m^2
# Globalno horizontalno sunčevo zracenje: 0 W/m^2
# Procenjeno suncevo zracenje: 0 W/m^2
# Solarni elevacioni ugao: -28.91 stepeni
# Solarni satni ugao (zastarjelo): -90 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-24 u 19:45:48.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:18
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-24 18:14
# Posljednji vremenski ciklus (zastarijelo): 2023-12-24:18
# Vrijeme opservacije (Unix timestamp): 1703441647
# Naziv grada: Sarajevo
# ...
#
# ----------------------------------------
#
# Mjerenje za 2023-12-25 u 13:16:59.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:19
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-25 12:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-25:12
# Vrijeme opservacije (Unix timestamp): 1703505600
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 956.3 mb
# Pritisak na nivou mora: 1016 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 15 °C
# Aparentna temperatura: 15 °C
# Relativna vlaznost: 41 %
# Tacka rose: 1.8 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.8305748
# Indeks kvaliteta vazduha (AQI): 145
# Difuzno horizontalno suncevo zracenje: 80.73 W/m^2
# Direktno normalno sunčevo zracenje: 713.33 W/m^2
# Globalno horizontalno sunčevo zracenje: 326.56 W/m^2
# Procenjeno suncevo zracenje: 326.6 W/m^2
# Solarni elevacioni ugao: 20.74 stepeni
# Solarni satni ugao (zastarjelo): 45 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-25 u 13:32:00.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:19
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-25 12:02
# Posljednji vremenski ciklus (zastarijelo): 2023-12-25:12
# Vrijeme opservacije (Unix timestamp): 1703505720
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 956.3 mb
# Pritisak na nivou mora: 1016 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 15 °C
# Aparentna temperatura: 15 °C
# Relativna vlaznost: 41 %
# Tacka rose: 1.8 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.8305748
# Indeks kvaliteta vazduha (AQI): 145
# Difuzno horizontalno suncevo zracenje: 80.73 W/m^2
# Direktno normalno sunčevo zracenje: 713.33 W/m^2
# Globalno horizontalno sunčevo zracenje: 326.56 W/m^2
# Procenjeno suncevo zracenje: 326.6 W/m^2
# Solarni elevacioni ugao: 20.74 stepeni
# Solarni satni ugao (zastarjelo): 45 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-25 u 13:47:01.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:19
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-25 12:17
# Posljednji vremenski ciklus (zastarijelo): 2023-12-25:12
# Vrijeme opservacije (Unix timestamp): 1703506621
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 956.3 mb
# Pritisak na nivou mora: 1016 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 15 °C
# Aparentna temperatura: 15 °C
# Relativna vlaznost: 41 %
# Tacka rose: 1.8 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.8305748
# Indeks kvaliteta vazduha (AQI): 89
# Difuzno horizontalno suncevo zracenje: 80.73 W/m^2
# Direktno normalno sunčevo zracenje: 713.33 W/m^2
# Globalno horizontalno sunčevo zracenje: 326.56 W/m^2
# Procenjeno suncevo zracenje: 326.6 W/m^2
# Solarni elevacioni ugao: 20.74 stepeni
# Solarni satni ugao (zastarjelo): 45 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-25 u 14:02:02.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:19
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-25 12:32
# Posljednji vremenski ciklus (zastarijelo): 2023-12-25:12
# Vrijeme opservacije (Unix timestamp): 1703507522
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 956.5 mb
# Pritisak na nivou mora: 1016 mb
# Brzina vjetra: 0.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 16 °C
# Aparentna temperatura: 16 °C
# Relativna vlaznost: 38 %
# Tacka rose: 1.7 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.5436186
# Indeks kvaliteta vazduha (AQI): 89
# Difuzno horizontalno suncevo zracenje: 71.09 W/m^2
# Direktno normalno sunčevo zracenje: 641.65 W/m^2
# Globalno horizontalno sunčevo zracenje: 242.8 W/m^2
# Procenjeno suncevo zracenje: 242.8 W/m^2
# Solarni elevacioni ugao: 16.21 stepeni
# Solarni satni ugao (zastarjelo): 45 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-25 u 14:17:03.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:19
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-25 13:00
# Posljednji vremenski ciklus (zastarijelo): 2023-12-25:13
# Vrijeme opservacije (Unix timestamp): 1703509200
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 956.5 mb
# Pritisak na nivou mora: 1016 mb
# Brzina vjetra: 1.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 140 stepeni
# Kratki opis smijera vjetra: SE
# Puni opis smijera vjetra: southeast
# Temperatura: 16 °C
# Aparentna temperatura: 16 °C
# Relativna vlaznost: 41 %
# Tacka rose: 2.7 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.5436186
# Indeks kvaliteta vazduha (AQI): 89
# Difuzno horizontalno suncevo zracenje: 71.09 W/m^2
# Direktno normalno sunčevo zracenje: 641.65 W/m^2
# Globalno horizontalno sunčevo zracenje: 242.8 W/m^2
# Procenjeno suncevo zracenje: 242.8 W/m^2
# Solarni elevacioni ugao: 16.21 stepeni
# Solarni satni ugao (zastarjelo): 67.5 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-25 u 14:32:04.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:19
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-25 13:02
# Posljednji vremenski ciklus (zastarijelo): 2023-12-25:13
# Vrijeme opservacije (Unix timestamp): 1703509324
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 956.5 mb
# Pritisak na nivou mora: 1016 mb
# Brzina vjetra: 1.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 140 stepeni
# Kratki opis smijera vjetra: SE
# Puni opis smijera vjetra: southeast
# Temperatura: 16 °C
# Aparentna temperatura: 16 °C
# Relativna vlaznost: 41 %
# Tacka rose: 2.7 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.5436186
# Indeks kvaliteta vazduha (AQI): 89
# Difuzno horizontalno suncevo zracenje: 71.09 W/m^2
# Direktno normalno sunčevo zracenje: 641.65 W/m^2
# Globalno horizontalno sunčevo zracenje: 242.8 W/m^2
# Procenjeno suncevo zracenje: 242.8 W/m^2
# Solarni elevacioni ugao: 16.21 stepeni
# Solarni satni ugao (zastarjelo): 67.5 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-25 u 14:47:05.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:19
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-25 13:17
# Posljednji vremenski ciklus (zastarijelo): 2023-12-25:13
# Vrijeme opservacije (Unix timestamp): 1703510225
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 956.5 mb
# Pritisak na nivou mora: 1016 mb
# Brzina vjetra: 1.5 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 140 stepeni
# Kratki opis smijera vjetra: SE
# Puni opis smijera vjetra: southeast
# Temperatura: 16 °C
# Aparentna temperatura: 16 °C
# Relativna vlaznost: 41 %
# Tacka rose: 2.7 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.5436186
# Indeks kvaliteta vazduha (AQI): 89
# Difuzno horizontalno suncevo zracenje: 71.09 W/m^2
# Direktno normalno sunčevo zracenje: 641.65 W/m^2
# Globalno horizontalno sunčevo zracenje: 242.8 W/m^2
# Procenjeno suncevo zracenje: 242.8 W/m^2
# Solarni elevacioni ugao: 16.21 stepeni
# Solarni satni ugao (zastarjelo): 67.5 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-25 u 15:02:06.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:19
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-25 13:32
# Posljednji vremenski ciklus (zastarijelo): 2023-12-25:13
# Vrijeme opservacije (Unix timestamp): 1703511126
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 956.3 mb
# Pritisak na nivou mora: 1016 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 250 stepeni
# Kratki opis smijera vjetra: WSW
# Puni opis smijera vjetra: west-southwest
# Temperatura: 15 °C
# Aparentna temperatura: 15 °C
# Relativna vlaznost: 47 %
# Tacka rose: 3.8 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.3154413
# Indeks kvaliteta vazduha (AQI): 92
# Difuzno horizontalno suncevo zracenje: 53.03 W/m^2
# Direktno normalno sunčevo zracenje: 486.73 W/m^2
# Globalno horizontalno sunčevo zracenje: 125.3 W/m^2
# Procenjeno suncevo zracenje: 125.3 W/m^2
# Solarni elevacioni ugao: 9.57 stepeni
# Solarni satni ugao (zastarjelo): 67.5 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-25 u 15:17:07.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:19
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-25 13:47
# Posljednji vremenski ciklus (zastarijelo): 2023-12-25:13
# Vrijeme opservacije (Unix timestamp): 1703512027
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 956.3 mb
# Pritisak na nivou mora: 1016 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 250 stepeni
# Kratki opis smijera vjetra: WSW
# Puni opis smijera vjetra: west-southwest
# Temperatura: 15 °C
# Aparentna temperatura: 15 °C
# Relativna vlaznost: 47 %
# Tacka rose: 3.8 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.3154413
# Indeks kvaliteta vazduha (AQI): 92
# Difuzno horizontalno suncevo zracenje: 53.03 W/m^2
# Direktno normalno sunčevo zracenje: 486.73 W/m^2
# Globalno horizontalno sunčevo zracenje: 125.3 W/m^2
# Procenjeno suncevo zracenje: 125.3 W/m^2
# Solarni elevacioni ugao: 9.57 stepeni
# Solarni satni ugao (zastarjelo): 67.5 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-25 u 15:32:08.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:19
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-25 14:02
# Posljednji vremenski ciklus (zastarijelo): 2023-12-25:14
# Vrijeme opservacije (Unix timestamp): 1703512928
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 956.5 mb
# Pritisak na nivou mora: 1016 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 16 °C
# Aparentna temperatura: 16 °C
# Relativna vlaznost: 41 %
# Tacka rose: 2.7 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.3154413
# Indeks kvaliteta vazduha (AQI): 92
# Difuzno horizontalno suncevo zracenje: 53.03 W/m^2
# Direktno normalno sunčevo zracenje: 486.73 W/m^2
# Globalno horizontalno sunčevo zracenje: 125.3 W/m^2
# Procenjeno suncevo zracenje: 125.3 W/m^2
# Solarni elevacioni ugao: 9.57 stepeni
# Solarni satni ugao (zastarjelo): 90 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-25 u 15:47:09.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:19
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-25 14:17
# Posljednji vremenski ciklus (zastarijelo): 2023-12-25:14
# Vrijeme opservacije (Unix timestamp): 1703513829
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 956.5 mb
# Pritisak na nivou mora: 1016 mb
# Brzina vjetra: 1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 0 stepeni
# Kratki opis smijera vjetra: N
# Puni opis smijera vjetra: north
# Temperatura: 16 °C
# Aparentna temperatura: 16 °C
# Relativna vlaznost: 41 %
# Tacka rose: 2.7 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.3154413
# Indeks kvaliteta vazduha (AQI): 92
# Difuzno horizontalno suncevo zracenje: 53.03 W/m^2
# Direktno normalno sunčevo zracenje: 486.73 W/m^2
# Globalno horizontalno sunčevo zracenje: 125.3 W/m^2
# Procenjeno suncevo zracenje: 125.3 W/m^2
# Solarni elevacioni ugao: 9.57 stepeni
# Solarni satni ugao (zastarjelo): 90 stepeni
#
# ----------------------------------------
#
# Mjerenje za 2023-12-25 u 16:02:10.
# Broj opservacija: None
# Geografska sirina: 43.84864
# Geografska duzina: 18.35644
# Vrijeme izlaska sunca (UTC): 06:19
# Vrijeme zalaska sunca (UTC): 15:14
# Vremenska zona: Europe/Sarajevo
# ID stanice (zastarijelo): LQSA
# Izvori podataka: ['LQSA', 'radar', 'satellite']
# Vrijeme posljednje opservacije: 2023-12-25 14:32
# Posljednji vremenski ciklus (zastarijelo): 2023-12-25:14
# Vrijeme opservacije (Unix timestamp): 1703514730
# Naziv grada: Sarajevo
# Kod zemlje: BA
# Kod drzave: 01
# Pritisak: 955.9 mb
# Pritisak na nivou mora: 1016 mb
# Brzina vjetra: 2.1 m/s
# Brzina vjetra (naleti): None m/s
# Smijer vetra: 180 stepeni
# Kratki opis smijera vjetra: S
# Puni opis smijera vjetra: south
# Temperatura: 13 °C
# Aparentna temperatura: 13 °C
# Relativna vlaznost: 50 %
# Tacka rose: 2.8 °C
# Oblacnost: 0 %
# Dio dana: d (d = dan / n = noć)
# Vremenski uslovi:
#    Ikona: c01d
#    Kod: 800
#    Opis: Clear sky
# Vidljivost: 16 km
# Padavine: 0 mm/h
# Snijeg: 0 mm/h
# UV indeks: 1.2502044
# Indeks kvaliteta vazduha (AQI): 92
# Difuzno horizontalno suncevo zracenje: 15.47 W/m^2
# Direktno normalno sunčevo zracenje: 86.85 W/m^2
# Globalno horizontalno sunčevo zracenje: 9.39 W/m^2
# Procenjeno suncevo zracenje: 9.4 W/m^2
# Solarni elevacioni ugao: 1.34 stepeni
# Solarni satni ugao (zastarjelo): 90 stepeni
#
# ----------------------------------------
