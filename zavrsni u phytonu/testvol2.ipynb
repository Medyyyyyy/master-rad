# %%
import requests
from datetime import datetime, timedelta
import time

def get_energy_data(api_key, city='Sarajevo', country='BA'):
    api_url = 'https://api.weatherbit.io/v2.0/current'

    # Postavljanje trenutnog vremena
    current_datetime = datetime.now()
    current_day_start = datetime(current_datetime.year, current_datetime.month, current_datetime.day, 19, 10, 0)

    # Ako je trenutno vreme pre nego što dan počne, koristimo prethodni dan
    if current_datetime < current_day_start:
        current_day_start -= timedelta(days=1)

    # Parametri zahteva
    params = {
        'city': city,
        'country': country,
        'key': api_key,
    }

    try:
        response = requests.get(api_url, params=params)

        # Provera da li je zahtev uspešan (HTTP status kod 200)
        if response.status_code == 200:
            data = response.json()

            # Rad sa podacima
            for entry in data['data']:
                time = parse_datetime(entry.get('ob_time', '')).strftime('%H:%M:%S')  # Prilagođeno za 'current'

                # Ispis svih dostupnih parametara
                for key, value in entry.items():
                    print(f"{key}: {value}")

                print("\n" + "-"*40 + "\n")

            # Provera je li došlo do promene dana
            if current_datetime > current_day_start:
                print(f"\nNovi dan: {current_datetime.date()}\n")

        else:
            print(f'Error {response.status_code}: {response.text}')

    except Exception as e:
        print(f'Error: {e}')

def parse_datetime(dt_str):
    try:
        # Pokušaj parsiranja datuma i vremena
        return datetime.strptime(dt_str, '%Y-%m-%d %H:%M:%S')  # Prilagođeno za 'current'
    except ValueError:
        # Obrada slučaja kada parsiranje ne uspe
        return datetime.min

# Postavljanje periodičnog zadatka
while True:
    get_energy_data(api_key='abd79c512df344da80c500911fd874fe')
    time.sleep(900)  # Pauza od 900 sekundi (15 minuta) pre sledećeg poziva
# Out:
# app_temp: 1.7
# aqi: 89
# city_name: Sarajevo
# clouds: 53
# country_code: BA
# datetime: 2023-12-22:17
# dewpt: 4
# dhi: 0
# dni: 0
# elev_angle: -29.11
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 17:40
# pod: n
# precip: 0
# pres: 942.8
# rh: 100
# slp: 1004
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 4
# timezone: Europe/Sarajevo
# ts: 1703266838
# uv: 0
# vis: 16
# weather: {'description': 'Scattered clouds', 'code': 802, 'icon': 'c02n'}
# wind_cdir: ESE
# wind_cdir_full: east-southeast
# wind_dir: 120
# wind_spd: 2.6
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 1.7
# aqi: 89
# city_name: Sarajevo
# clouds: 49
# country_code: BA
# datetime: 2023-12-22:18
# dewpt: 4
# dhi: 0
# dni: 0
# elev_angle: -29.11
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 18:00
# pod: n
# precip: 0
# pres: 942.8
# rh: 100
# slp: 1004
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 4
# timezone: Europe/Sarajevo
# ts: 1703268000
# uv: 0
# vis: 16
# weather: {'description': 'Scattered clouds', 'code': 802, 'icon': 'c02n'}
# wind_cdir: E
# wind_cdir_full: east
# wind_dir: 100
# wind_spd: 2.6
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 1.7
# aqi: 89
# city_name: Sarajevo
# clouds: 53
# country_code: BA
# datetime: 2023-12-22:18
# dewpt: 4
# dhi: 0
# dni: 0
# elev_angle: -29.11
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 18:10
# pod: n
# precip: 0
# pres: 942.8
# rh: 100
# slp: 1004
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 4
# timezone: Europe/Sarajevo
# ts: 1703268640
# uv: 0
# vis: 16
# weather: {'code': 802, 'icon': 'c02n', 'description': 'Scattered clouds'}
# wind_cdir: E
# wind_cdir_full: east
# wind_dir: 100
# wind_spd: 2.6
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 2.1
# aqi: 89
# city_name: Sarajevo
# clouds: 57
# country_code: BA
# datetime: 2023-12-22:18
# dewpt: 4
# dhi: 0
# dni: 0
# elev_angle: -29.11
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 18:30
# pod: n
# precip: 0
# pres: 941.8
# rh: 100
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 4
# timezone: Europe/Sarajevo
# ts: 1703269800
# uv: 0
# vis: 16
# weather: {'description': 'Scattered clouds', 'code': 802, 'icon': 'c02n'}
# wind_cdir: E
# wind_cdir_full: east
# wind_dir: 90
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 2.1
# aqi: 104
# city_name: Sarajevo
# clouds: 58
# country_code: BA
# datetime: 2023-12-22:18
# dewpt: 4
# dhi: 0
# dni: 0
# elev_angle: -39.92
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 18:40
# pod: n
# precip: 0
# pres: 941.8
# rh: 100
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 4
# timezone: Europe/Sarajevo
# ts: 1703270442
# uv: 0
# vis: 16
# weather: {'description': 'Scattered clouds', 'code': 802, 'icon': 'c02n'}
# wind_cdir: E
# wind_cdir_full: east
# wind_dir: 90
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 2.5
# aqi: 104
# city_name: Sarajevo
# clouds: 83
# country_code: BA
# datetime: 2023-12-22:19
# dewpt: 3
# dhi: 0
# dni: 0
# elev_angle: -39.92
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 19:00
# pod: n
# precip: 0
# pres: 941.6
# rh: 100
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 3
# timezone: Europe/Sarajevo
# ts: 1703271600
# uv: 0
# vis: 16
# weather: {'code': 803, 'icon': 'c03n', 'description': 'Broken clouds'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 2.5
# aqi: 104
# city_name: Sarajevo
# clouds: 83
# country_code: BA
# datetime: 2023-12-22:19
# dewpt: 3
# dhi: 0
# dni: 0
# elev_angle: -39.92
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 19:10
# pod: n
# precip: 0
# pres: 941.6
# rh: 100
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 3
# timezone: Europe/Sarajevo
# ts: 1703272244
# uv: 0
# vis: 16
# weather: {'description': 'Broken clouds', 'code': 803, 'icon': 'c03n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 1.4
# aqi: 104
# city_name: Sarajevo
# clouds: 84
# country_code: BA
# datetime: 2023-12-22:19
# dewpt: 2
# dhi: 0
# dni: 0
# elev_angle: -39.92
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 19:30
# pod: n
# precip: 0
# pres: 941.4
# rh: 100
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 2
# timezone: Europe/Sarajevo
# ts: 1703273400
# uv: 0
# vis: 16
# weather: {'description': 'Broken clouds', 'code': 803, 'icon': 'c03n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 1.4
# aqi: 129
# city_name: Sarajevo
# clouds: 56
# country_code: BA
# datetime: 2023-12-22:19
# dewpt: 2
# dhi: 0
# dni: 0
# elev_angle: -50.52
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 19:40
# pod: n
# precip: 0
# pres: 941.4
# rh: 100
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 2
# timezone: Europe/Sarajevo
# ts: 1703274045
# uv: 0
# vis: 16
# weather: {'description': 'Scattered clouds', 'code': 802, 'icon': 'c02n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 1.4
# aqi: 139
# city_name: Sarajevo
# clouds: 59
# country_code: BA
# datetime: 2023-12-22:20
# dewpt: 2
# dhi: 0
# dni: 0
# elev_angle: -50.52
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 20:00
# pod: n
# precip: 0
# pres: 941.4
# rh: 100
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 2
# timezone: Europe/Sarajevo
# ts: 1703275200
# uv: 0
# vis: 16
# weather: {'code': 802, 'icon': 'c02n', 'description': 'Scattered clouds'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 1.4
# aqi: 139
# city_name: Sarajevo
# clouds: 80
# country_code: BA
# datetime: 2023-12-22:20
# dewpt: 2
# dhi: 0
# dni: 0
# elev_angle: -50.52
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 20:10
# pod: n
# precip: 0
# pres: 941.4
# rh: 100
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 2
# timezone: Europe/Sarajevo
# ts: 1703275847
# uv: 0
# vis: 16
# weather: {'description': 'Broken clouds', 'code': 803, 'icon': 'c03n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 1.4
# aqi: 139
# city_name: Sarajevo
# clouds: 54
# country_code: BA
# datetime: 2023-12-22:20
# dewpt: 2
# dhi: 0
# dni: 0
# elev_angle: -50.52
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 20:30
# pod: n
# precip: 0
# pres: 941.4
# rh: 100
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 2
# timezone: Europe/Sarajevo
# ts: 1703277000
# uv: 0
# vis: 16
# weather: {'icon': 'c02n', 'description': 'Scattered clouds', 'code': 802}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 1.4
# aqi: 151
# city_name: Sarajevo
# clouds: 54
# country_code: BA
# datetime: 2023-12-22:20
# dewpt: 2
# dhi: 0
# dni: 0
# elev_angle: -60.25
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 20:40
# pod: n
# precip: 0
# pres: 941.4
# rh: 100
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 2
# timezone: Europe/Sarajevo
# ts: 1703277649
# uv: 0
# vis: 16
# weather: {'description': 'Scattered clouds', 'code': 802, 'icon': 'c02n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 2.8
# aqi: 139
# city_name: Sarajevo
# clouds: 87
# country_code: BA
# datetime: 2023-12-22:21
# dewpt: 2
# dhi: 0
# dni: 0
# elev_angle: -60.25
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 21:00
# pod: n
# precip: 0
# pres: 941.4
# rh: 100
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 2
# timezone: Europe/Sarajevo
# ts: 1703278800
# uv: 0
# vis: 16
# weather: {'description': 'Fog', 'code': 741, 'icon': 'a05n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 0.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 2.8
# aqi: 139
# city_name: Sarajevo
# clouds: 86
# country_code: BA
# datetime: 2023-12-22:21
# dewpt: 2
# dhi: 0
# dni: 0
# elev_angle: -60.25
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 21:10
# pod: n
# precip: 0
# pres: 941.4
# rh: 100
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 2
# timezone: Europe/Sarajevo
# ts: 1703279451
# uv: 0
# vis: 16
# weather: {'description': 'Fog', 'code': 741, 'icon': 'a05n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 0.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 0.6
# aqi: 139
# city_name: Sarajevo
# clouds: 86
# country_code: BA
# datetime: 2023-12-22:21
# dewpt: 2
# dhi: 0
# dni: 0
# elev_angle: -60.25
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 21:30
# pod: n
# precip: 0
# pres: 941.4
# rh: 100
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 2
# timezone: Europe/Sarajevo
# ts: 1703280600
# uv: 0
# vis: 16
# weather: {'description': 'Fog', 'code': 741, 'icon': 'a05n'}
# wind_cdir: WSW
# wind_cdir_full: west-southwest
# wind_dir: 240
# wind_spd: 1.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 0.6
# aqi: 134
# city_name: Sarajevo
# clouds: 86
# country_code: BA
# datetime: 2023-12-22:21
# dewpt: 2
# dhi: 0
# dni: 0
# elev_angle: -67.55
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 21:40
# pod: n
# precip: 0
# pres: 941.4
# rh: 100
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 2
# timezone: Europe/Sarajevo
# ts: 1703281253
# uv: 0
# vis: 16
# weather: {'code': 741, 'icon': 'a05n', 'description': 'Fog'}
# wind_cdir: WSW
# wind_cdir_full: west-southwest
# wind_dir: 240
# wind_spd: 1.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 1.4
# aqi: 134
# city_name: Sarajevo
# clouds: 87
# country_code: BA
# datetime: 2023-12-22:22
# dewpt: 2
# dhi: 0
# dni: 0
# elev_angle: -67.55
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 22:00
# pod: n
# precip: 0
# pres: 941.4
# rh: 100
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 2
# timezone: Europe/Sarajevo
# ts: 1703282400
# uv: 0
# vis: 16
# weather: {'description': 'Fog', 'code': 741, 'icon': 'a05n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 1.4
# aqi: 115
# city_name: Sarajevo
# clouds: 85
# country_code: BA
# datetime: 2023-12-22:22
# dewpt: 2
# dhi: 0
# dni: 0
# elev_angle: -67.55
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 22:10
# pod: n
# precip: 0
# pres: 941.4
# rh: 100
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 2
# timezone: Europe/Sarajevo
# ts: 1703283054
# uv: 0
# vis: 16
# weather: {'description': 'Fog', 'code': 741, 'icon': 'a05n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 1.4
# aqi: 115
# city_name: Sarajevo
# clouds: 83
# country_code: BA
# datetime: 2023-12-22:22
# dewpt: 2
# dhi: 0
# dni: 0
# elev_angle: -67.55
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 22:30
# pod: n
# precip: 0
# pres: 941.4
# rh: 100
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 2
# timezone: Europe/Sarajevo
# ts: 1703284200
# uv: 0
# vis: 16
# weather: {'description': 'Fog', 'code': 741, 'icon': 'a05n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-22
#
# app_temp: 1.4
# aqi: 95
# city_name: Sarajevo
# clouds: 84
# country_code: BA
# datetime: 2023-12-22:22
# dewpt: 2
# dhi: 0
# dni: 0
# elev_angle: -69.39
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 22:40
# pod: n
# precip: 0
# pres: 941.4
# rh: 100
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 2
# timezone: Europe/Sarajevo
# ts: 1703284857
# uv: 0
# vis: 16
# weather: {'description': 'Fog', 'code': 741, 'icon': 'a05n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 0.6
# aqi: 95
# city_name: Sarajevo
# clouds: 86
# country_code: BA
# datetime: 2023-12-22:23
# dewpt: 2
# dhi: 0
# dni: 0
# elev_angle: -69.39
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 23:00
# pod: n
# precip: 0
# pres: 940.5
# rh: 100
# slp: 1002
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 2
# timezone: Europe/Sarajevo
# ts: 1703286000
# uv: 0
# vis: 16
# weather: {'code': 741, 'description': 'Fog', 'icon': 'a05n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 0.6
# aqi: 95
# city_name: Sarajevo
# clouds: 86
# country_code: BA
# datetime: 2023-12-22:23
# dewpt: 2
# dhi: 0
# dni: 0
# elev_angle: -69.39
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 23:10
# pod: n
# precip: 0
# pres: 940.5
# rh: 100
# slp: 1002
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 2
# timezone: Europe/Sarajevo
# ts: 1703286659
# uv: 0
# vis: 16
# weather: {'description': 'Fog', 'code': 741, 'icon': 'a05n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 1.4
# aqi: 95
# city_name: Sarajevo
# clouds: 86
# country_code: BA
# datetime: 2023-12-22:23
# dewpt: 2
# dhi: 0
# dni: 0
# elev_angle: -69.39
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 23:30
# pod: n
# precip: 0
# pres: 940.5
# rh: 100
# slp: 1002
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 2
# timezone: Europe/Sarajevo
# ts: 1703287800
# uv: 0
# vis: 16
# weather: {'code': 741, 'icon': 'a05n', 'description': 'Fog'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 1.4
# aqi: 91
# city_name: Sarajevo
# clouds: 83
# country_code: BA
# datetime: 2023-12-22:23
# dewpt: 2
# dhi: 0
# dni: 0
# elev_angle: -64.53
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-22 23:38
# pod: n
# precip: 0
# pres: 940.5
# rh: 100
# slp: 1002
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 2
# timezone: Europe/Sarajevo
# ts: 1703288285
# uv: 0
# vis: 16
# weather: {'code': 741, 'icon': 'a05n', 'description': 'Fog'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 0.3
# aqi: 91
# city_name: Sarajevo
# clouds: 54
# country_code: BA
# datetime: 2023-12-23:00
# dewpt: 1
# dhi: 0
# dni: 0
# elev_angle: -64.53
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 00:00
# pod: n
# precip: 0
# pres: 940.2
# rh: 100
# slp: 1002
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 1
# timezone: Europe/Sarajevo
# ts: 1703289600
# uv: 0
# vis: 16
# weather: {'code': 741, 'icon': 'a05n', 'description': 'Fog'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 0.3
# aqi: 91
# city_name: Sarajevo
# clouds: 56
# country_code: BA
# datetime: 2023-12-23:00
# dewpt: 1
# dhi: 0
# dni: 0
# elev_angle: -64.53
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 00:08
# pod: n
# precip: 0
# pres: 940.2
# rh: 100
# slp: 1002
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 1
# timezone: Europe/Sarajevo
# ts: 1703290087
# uv: 0
# vis: 16
# weather: {'code': 741, 'icon': 'a05n', 'description': 'Fog'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 0.3
# aqi: 91
# city_name: Sarajevo
# clouds: 80
# country_code: BA
# datetime: 2023-12-23:00
# dewpt: 1
# dhi: 0
# dni: 0
# elev_angle: -64.53
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 00:23
# pod: n
# precip: 0
# pres: 940.2
# rh: 100
# slp: 1002
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 1
# timezone: Europe/Sarajevo
# ts: 1703290988
# uv: 0
# vis: 16
# weather: {'code': 741, 'icon': 'a05n', 'description': 'Fog'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 1.7
# aqi: 100
# city_name: Sarajevo
# clouds: 85
# country_code: BA
# datetime: 2023-12-23:00
# dewpt: 1
# dhi: 0
# dni: 0
# elev_angle: -55.78
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 00:38
# pod: n
# precip: 0
# pres: 939.3
# rh: 100
# slp: 1001
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 1
# timezone: Europe/Sarajevo
# ts: 1703291889
# uv: 0
# vis: 16
# weather: {'code': 741, 'icon': 'a05n', 'description': 'Fog'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 0.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 0.3
# aqi: 100
# city_name: Sarajevo
# clouds: 80
# country_code: BA
# datetime: 2023-12-23:01
# dewpt: 1
# dhi: 0
# dni: 0
# elev_angle: -55.78
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 01:00
# pod: n
# precip: 0
# pres: 940.2
# rh: 100
# slp: 1002
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 1
# timezone: Europe/Sarajevo
# ts: 1703293200
# uv: 0
# vis: 16
# weather: {'code': 741, 'icon': 'a05n', 'description': 'Fog'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 0.3
# aqi: 100
# city_name: Sarajevo
# clouds: 80
# country_code: BA
# datetime: 2023-12-23:01
# dewpt: 1
# dhi: 0
# dni: 0
# elev_angle: -55.78
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 01:08
# pod: n
# precip: 0
# pres: 940.2
# rh: 100
# slp: 1002
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 1
# timezone: Europe/Sarajevo
# ts: 1703293691
# uv: 0
# vis: 7
# weather: {'icon': 'a05n', 'description': 'Fog', 'code': 741}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: -1.4
# aqi: 100
# city_name: Sarajevo
# clouds: 80
# country_code: BA
# datetime: 2023-12-23:01
# dewpt: 1
# dhi: 0
# dni: 0
# elev_angle: -55.78
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 01:30
# pod: n
# precip: 0
# pres: 940.2
# rh: 100
# slp: 1002
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 1
# timezone: Europe/Sarajevo
# ts: 1703295000
# uv: 0
# vis: 7
# weather: {'code': 741, 'icon': 'a05n', 'description': 'Fog'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: -1.4
# aqi: 107
# city_name: Sarajevo
# clouds: 50
# country_code: BA
# datetime: 2023-12-23:01
# dewpt: 1
# dhi: 0
# dni: 0
# elev_angle: -45.51
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 01:38
# pod: n
# precip: 0
# pres: 940.2
# rh: 100
# slp: 1002
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 1
# timezone: Europe/Sarajevo
# ts: 1703295493
# uv: 0
# vis: 7
# weather: {'description': 'Fog', 'code': 741, 'icon': 'a05n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: -1.4
# aqi: 121
# city_name: Sarajevo
# clouds: 42
# country_code: BA
# datetime: 2023-12-23:02
# dewpt: 1
# dhi: 0
# dni: 0
# elev_angle: -45.51
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 02:00
# pod: n
# precip: 0
# pres: 939.3
# rh: 100
# slp: 1001
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 1
# timezone: Europe/Sarajevo
# ts: 1703296800
# uv: 0
# vis: 7
# weather: {'icon': 'a05n', 'description': 'Fog', 'code': 741}
# wind_cdir: SE
# wind_cdir_full: southeast
# wind_dir: 140
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: -1.4
# aqi: 121
# city_name: Sarajevo
# clouds: 42
# country_code: BA
# datetime: 2023-12-23:02
# dewpt: 1
# dhi: 0
# dni: 0
# elev_angle: -45.51
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 02:08
# pod: n
# precip: 0
# pres: 939.3
# rh: 100
# slp: 1001
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 1
# timezone: Europe/Sarajevo
# ts: 1703297295
# uv: 0
# vis: 7
# weather: {'description': 'Fog', 'code': 741, 'icon': 'a05n'}
# wind_cdir: SE
# wind_cdir_full: southeast
# wind_dir: 140
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 3.3
# aqi: 121
# city_name: Sarajevo
# clouds: 42
# country_code: BA
# datetime: 2023-12-23:02
# dewpt: 0.9
# dhi: 0
# dni: 0
# elev_angle: -45.51
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 02:30
# pod: n
# precip: 0
# pres: 940.2
# rh: 75
# slp: 1001
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 5
# timezone: Europe/Sarajevo
# ts: 1703298600
# uv: 0
# vis: 7
# weather: {'description': 'Scattered clouds', 'code': 802, 'icon': 'c02n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 3.3
# aqi: 134
# city_name: Sarajevo
# clouds: 42
# country_code: BA
# datetime: 2023-12-23:02
# dewpt: 0.9
# dhi: 0
# dni: 0
# elev_angle: -34.76
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 02:38
# pod: n
# precip: 0
# pres: 940.2
# rh: 75
# slp: 1001
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 5
# timezone: Europe/Sarajevo
# ts: 1703299097
# uv: 0
# vis: 7
# weather: {'icon': 'c02n', 'description': 'Scattered clouds', 'code': 802}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 3.3
# aqi: 97
# city_name: Sarajevo
# clouds: 42
# country_code: BA
# datetime: 2023-12-23:03
# dewpt: 0.9
# dhi: 0
# dni: 0
# elev_angle: -34.76
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 03:00
# pod: n
# precip: 0
# pres: 940.2
# rh: 75
# slp: 1001
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 5
# timezone: Europe/Sarajevo
# ts: 1703300400
# uv: 0
# vis: 7
# weather: {'code': 802, 'icon': 'c02n', 'description': 'Scattered clouds'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 3.3
# aqi: 97
# city_name: Sarajevo
# clouds: 42
# country_code: BA
# datetime: 2023-12-23:03
# dewpt: 0.9
# dhi: 0
# dni: 0
# elev_angle: -34.76
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 03:08
# pod: n
# precip: 0
# pres: 940.2
# rh: 75
# slp: 1001
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 5
# timezone: Europe/Sarajevo
# ts: 1703300899
# uv: 0
# vis: 3
# weather: {'icon': 'c02n', 'description': 'Scattered clouds', 'code': 802}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 5.7
# aqi: 97
# city_name: Sarajevo
# clouds: 40
# country_code: BA
# datetime: 2023-12-23:03
# dewpt: 0.9
# dhi: 0
# dni: 0
# elev_angle: -34.76
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 03:30
# pod: n
# precip: 0
# pres: 941.5
# rh: 65
# slp: 1002
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 7
# timezone: Europe/Sarajevo
# ts: 1703302200
# uv: 0
# vis: 3
# weather: {'icon': 'c02n', 'description': 'Few clouds', 'code': 801}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 5.7
# aqi: 97
# city_name: Sarajevo
# clouds: 40
# country_code: BA
# datetime: 2023-12-23:03
# dewpt: 0.9
# dhi: 0
# dni: 0
# elev_angle: -24
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 03:38
# pod: n
# precip: 0
# pres: 941.5
# rh: 65
# slp: 1002
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 7
# timezone: Europe/Sarajevo
# ts: 1703302701
# uv: 0
# vis: 3
# weather: {'description': 'Few clouds', 'code': 801, 'icon': 'c02n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 10
# aqi: 97
# city_name: Sarajevo
# clouds: 44
# country_code: BA
# datetime: 2023-12-23:04
# dewpt: -0.3
# dhi: 0
# dni: 0
# elev_angle: -24
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 04:00
# pod: n
# precip: 0
# pres: 942.1
# rh: 49
# slp: 1002
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 10
# timezone: Europe/Sarajevo
# ts: 1703304000
# uv: 0
# vis: 3
# weather: {'description': 'Scattered clouds', 'code': 802, 'icon': 'c02n'}
# wind_cdir: W
# wind_cdir_full: west
# wind_dir: 280
# wind_spd: 5.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 10
# aqi: 90
# city_name: Sarajevo
# clouds: 42
# country_code: BA
# datetime: 2023-12-23:04
# dewpt: -0.3
# dhi: 0
# dni: 0
# elev_angle: -24
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 04:08
# pod: n
# precip: 0
# pres: 942.1
# rh: 49
# slp: 1002
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 10
# timezone: Europe/Sarajevo
# ts: 1703304503
# uv: 0
# vis: 16
# weather: {'code': 802, 'icon': 'c02n', 'description': 'Scattered clouds'}
# wind_cdir: W
# wind_cdir_full: west
# wind_dir: 280
# wind_spd: 5.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 4.2
# aqi: 90
# city_name: Sarajevo
# clouds: 44
# country_code: BA
# datetime: 2023-12-23:04
# dewpt: 2.9
# dhi: 0
# dni: 0
# elev_angle: -24
# ghi: 0
# gust: 3.6
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 04:38
# pod: n
# precip: 0
# pres: 935
# rh: 85
# slp: 1004.5
# snow: 0
# solar_rad: 0
# sources: ['analysis', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 5.3
# timezone: Europe/Sarajevo
# ts: 1703306304
# uv: 0
# vis: 16
# weather: {'icon': 'c02n', 'description': 'Scattered clouds', 'code': 802}
# wind_cdir: WSW
# wind_cdir_full: west-southwest
# wind_dir: 252
# wind_spd: 1.54
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 4.2
# aqi: 90
# city_name: Sarajevo
# clouds: 42
# country_code: BA
# datetime: 2023-12-23:04
# dewpt: 2.9
# dhi: 0
# dni: 0
# elev_angle: -13.55
# ghi: 0
# gust: 3.6
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 04:53
# pod: n
# precip: 0
# pres: 935
# rh: 85
# slp: 1004.5
# snow: 0
# solar_rad: 0
# sources: ['analysis', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 5.3
# timezone: Europe/Sarajevo
# ts: 1703307205
# uv: 0
# vis: 16
# weather: {'description': 'Scattered clouds', 'code': 802, 'icon': 'c02n'}
# wind_cdir: WSW
# wind_cdir_full: west-southwest
# wind_dir: 252
# wind_spd: 1.54
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 4.2
# aqi: 90
# city_name: Sarajevo
# clouds: 42
# country_code: BA
# datetime: 2023-12-23:05
# dewpt: 2.9
# dhi: 0
# dni: 0
# elev_angle: -13.55
# ghi: 0
# gust: 3.6
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 05:08
# pod: n
# precip: 0
# pres: 935
# rh: 85
# slp: 1004.5
# snow: 0
# solar_rad: 0
# sources: ['analysis', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 5.3
# timezone: Europe/Sarajevo
# ts: 1703308106
# uv: 0
# vis: 16
# weather: {'description': 'Scattered clouds', 'code': 802, 'icon': 'c02n'}
# wind_cdir: WSW
# wind_cdir_full: west-southwest
# wind_dir: 252
# wind_spd: 1.54
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 4.8
# aqi: 90
# city_name: Sarajevo
# clouds: 42
# country_code: BA
# datetime: 2023-12-23:05
# dewpt: 2.9
# dhi: 0
# dni: 0
# elev_angle: -13.55
# ghi: 0
# gust: 3.6
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 05:23
# pod: n
# precip: 0
# pres: 936
# rh: 82
# slp: 1005.5
# snow: 0
# solar_rad: 0
# sources: ['analysis', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 5.8
# timezone: Europe/Sarajevo
# ts: 1703309007
# uv: 0
# vis: 16
# weather: {'code': 802, 'icon': 'c02n', 'description': 'Scattered clouds'}
# wind_cdir: W
# wind_cdir_full: west
# wind_dir: 268
# wind_spd: 1.54
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 9
# aqi: 76
# city_name: Sarajevo
# clouds: 42
# country_code: BA
# datetime: 2023-12-23:05
# dewpt: -0.1
# dhi: 0
# dni: 0
# elev_angle: -13.55
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 05:30
# pod: n
# precip: 0
# pres: 942.9
# rh: 53
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 9
# timezone: Europe/Sarajevo
# ts: 1703309400
# uv: 0
# vis: 1
# weather: {'code': 802, 'icon': 'c02n', 'description': 'Scattered clouds'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 9
# aqi: 76
# city_name: Sarajevo
# clouds: 42
# country_code: BA
# datetime: 2023-12-23:05
# dewpt: -0.1
# dhi: 0
# dni: 0
# elev_angle: -3.71
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 05:38
# pod: n
# precip: 0
# pres: 942.9
# rh: 53
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 9
# timezone: Europe/Sarajevo
# ts: 1703309909
# uv: 0
# vis: 1
# weather: {'code': 802, 'icon': 'c02n', 'description': 'Scattered clouds'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 5.7
# aqi: 76
# city_name: Sarajevo
# clouds: 42
# country_code: BA
# datetime: 2023-12-23:06
# dewpt: 0.9
# dhi: 0
# dni: 0
# elev_angle: -3.71
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 06:00
# pod: d
# precip: 0
# pres: 942.5
# rh: 65
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 7
# timezone: Europe/Sarajevo
# ts: 1703311200
# uv: 0
# vis: 1
# weather: {'description': 'Scattered clouds', 'code': 802, 'icon': 'c02d'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 5.7
# aqi: 76
# city_name: Sarajevo
# clouds: 42
# country_code: BA
# datetime: 2023-12-23:06
# dewpt: 0.9
# dhi: 0
# dni: 0
# elev_angle: -3.71
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 06:08
# pod: d
# precip: 0
# pres: 942.5
# rh: 65
# slp: 1003
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 7
# timezone: Europe/Sarajevo
# ts: 1703311710
# uv: 0
# vis: 1
# weather: {'description': 'Scattered clouds', 'code': 802, 'icon': 'c02d'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 5.7
# aqi: 76
# city_name: Sarajevo
# clouds: 44
# country_code: BA
# datetime: 2023-12-23:06
# dewpt: 0.9
# dhi: 0
# dni: 0
# elev_angle: -3.71
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 06:30
# pod: d
# precip: 0
# pres: 943.4
# rh: 65
# slp: 1004
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 7
# timezone: Europe/Sarajevo
# ts: 1703313000
# uv: 0
# vis: 1
# weather: {'code': 802, 'icon': 'c02d', 'description': 'Scattered clouds'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 5.7
# aqi: 61
# city_name: Sarajevo
# clouds: 50
# country_code: BA
# datetime: 2023-12-23:06
# dewpt: 0.9
# dhi: 36.55
# dni: 319.84
# elev_angle: 5.19
# ghi: 55.96
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 06:38
# pod: d
# precip: 0
# pres: 943.4
# rh: 65
# slp: 1004
# snow: 0
# solar_rad: 51.7
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:17
# sunset: 15:13
# temp: 7
# timezone: Europe/Sarajevo
# ts: 1703313512
# uv: 0.82589203
# vis: 1
# weather: {'code': 802, 'icon': 'c02d', 'description': 'Scattered clouds'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 4.9
# aqi: 61
# city_name: Sarajevo
# clouds: 42
# country_code: BA
# datetime: 2023-12-23:07
# dewpt: 1.9
# dhi: 36.55
# dni: 319.84
# elev_angle: 5.19
# ghi: 55.96
# gust: None
# h_angle: -67.5
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 07:00
# pod: d
# precip: 0
# pres: 944.3
# rh: 70
# slp: 1005
# snow: 0
# solar_rad: 53.6
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 7
# timezone: Europe/Sarajevo
# ts: 1703314800
# uv: 0.895494
# vis: 1
# weather: {'description': 'Scattered clouds', 'code': 802, 'icon': 'c02d'}
# wind_cdir: ENE
# wind_cdir_full: east-northeast
# wind_dir: 70
# wind_spd: 3.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 4.9
# aqi: 61
# city_name: Sarajevo
# clouds: 42
# country_code: BA
# datetime: 2023-12-23:07
# dewpt: 1.9
# dhi: 36.55
# dni: 319.84
# elev_angle: 5.19
# ghi: 55.96
# gust: None
# h_angle: -67.5
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 07:08
# pod: d
# precip: 0
# pres: 944.3
# rh: 70
# slp: 1005
# snow: 0
# solar_rad: 53.6
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 7
# timezone: Europe/Sarajevo
# ts: 1703315314
# uv: 0.895494
# vis: 5
# weather: {'description': 'Scattered clouds', 'code': 802, 'icon': 'c02d'}
# wind_cdir: ENE
# wind_cdir_full: east-northeast
# wind_dir: 70
# wind_spd: 3.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 9
# aqi: 61
# city_name: Sarajevo
# clouds: 50
# country_code: BA
# datetime: 2023-12-23:07
# dewpt: 3
# dhi: 36.55
# dni: 319.84
# elev_angle: 5.19
# ghi: 55.96
# gust: None
# h_angle: -67.5
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 07:30
# pod: d
# precip: 0
# pres: 944.8
# rh: 66
# slp: 1005
# snow: 0
# solar_rad: 51.7
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 9
# timezone: Europe/Sarajevo
# ts: 1703316600
# uv: 0.82589203
# vis: 5
# weather: {'description': 'Scattered clouds', 'code': 802, 'icon': 'c02d'}
# wind_cdir: E
# wind_cdir_full: east
# wind_dir: 100
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 9
# aqi: 80
# city_name: Sarajevo
# clouds: 50
# country_code: BA
# datetime: 2023-12-23:07
# dewpt: 3
# dhi: 62.42
# dni: 570.82
# elev_angle: 12.76
# ghi: 180.46
# gust: None
# h_angle: -67.5
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 07:38
# pod: d
# precip: 0
# pres: 944.8
# rh: 66
# slp: 1005
# snow: 0
# solar_rad: 166.8
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 9
# timezone: Europe/Sarajevo
# ts: 1703317116
# uv: 0.91655755
# vis: 5
# weather: {'icon': 'c02d', 'code': 802, 'description': 'Scattered clouds'}
# wind_cdir: E
# wind_cdir_full: east
# wind_dir: 100
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 8
# aqi: 78
# city_name: Sarajevo
# clouds: 50
# country_code: BA
# datetime: 2023-12-23:08
# dewpt: 2.9
# dhi: 62.42
# dni: 570.82
# elev_angle: 12.76
# ghi: 180.46
# gust: None
# h_angle: -45
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 08:00
# pod: d
# precip: 0
# pres: 944.6
# rh: 70
# slp: 1005
# snow: 0
# solar_rad: 166.8
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 8
# timezone: Europe/Sarajevo
# ts: 1703318400
# uv: 0.91655755
# vis: 5
# weather: {'description': 'Scattered clouds', 'code': 802, 'icon': 'c02d'}
# wind_cdir: ESE
# wind_cdir_full: east-southeast
# wind_dir: 120
# wind_spd: 1.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 8
# aqi: 78
# city_name: Sarajevo
# clouds: 27
# country_code: BA
# datetime: 2023-12-23:08
# dewpt: 2.9
# dhi: 62.42
# dni: 570.82
# elev_angle: 12.76
# ghi: 180.46
# gust: None
# h_angle: -45
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 08:08
# pod: d
# precip: 0
# pres: 944.6
# rh: 70
# slp: 1005
# snow: 0
# solar_rad: 178.8
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 8
# timezone: Europe/Sarajevo
# ts: 1703318918
# uv: 1.1386304
# vis: 16
# weather: {'description': 'Few clouds', 'code': 801, 'icon': 'c02d'}
# wind_cdir: ESE
# wind_cdir_full: east-southeast
# wind_dir: 120
# wind_spd: 1.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 10
# aqi: 78
# city_name: Sarajevo
# clouds: 27
# country_code: BA
# datetime: 2023-12-23:08
# dewpt: 3.9
# dhi: 62.42
# dni: 570.82
# elev_angle: 12.76
# ghi: 180.46
# gust: None
# h_angle: -45
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 08:30
# pod: d
# precip: 0
# pres: 945.9
# rh: 66
# slp: 1006
# snow: 0
# solar_rad: 178.8
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 10
# timezone: Europe/Sarajevo
# ts: 1703320200
# uv: 1.1386304
# vis: 16
# weather: {'description': 'Few clouds', 'code': 801, 'icon': 'c02d'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 10
# aqi: 76
# city_name: Sarajevo
# clouds: 27
# country_code: BA
# datetime: 2023-12-23:08
# dewpt: 3.9
# dhi: 76.16
# dni: 680.22
# elev_angle: 18.5
# ghi: 284.94
# gust: None
# h_angle: -45
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 08:38
# pod: d
# precip: 0
# pres: 945.9
# rh: 66
# slp: 1006
# snow: 0
# solar_rad: 282.3
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 10
# timezone: Europe/Sarajevo
# ts: 1703320720
# uv: 1.3621619
# vis: 16
# weather: {'description': 'Few clouds', 'code': 801, 'icon': 'c02d'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 11
# aqi: 78
# city_name: Sarajevo
# clouds: 27
# country_code: BA
# datetime: 2023-12-23:09
# dewpt: 2.8
# dhi: 76.16
# dni: 680.22
# elev_angle: 18.5
# ghi: 284.94
# gust: None
# h_angle: -22.5
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 09:00
# pod: d
# precip: 0
# pres: 947.1
# rh: 57
# slp: 1007
# snow: 0
# solar_rad: 282.3
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 11
# timezone: Europe/Sarajevo
# ts: 1703322000
# uv: 1.3621619
# vis: 16
# weather: {'icon': 'c02d', 'description': 'Few clouds', 'code': 801}
# wind_cdir: S
# wind_cdir_full: south
# wind_dir: 190
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 11
# aqi: 78
# city_name: Sarajevo
# clouds: 7
# country_code: BA
# datetime: 2023-12-23:09
# dewpt: 2.8
# dhi: 76.16
# dni: 680.22
# elev_angle: 18.5
# ghi: 284.94
# gust: None
# h_angle: -22.5
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 09:08
# pod: d
# precip: 0
# pres: 947.1
# rh: 57
# slp: 1007
# snow: 0
# solar_rad: 284.9
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 11
# timezone: Europe/Sarajevo
# ts: 1703322522
# uv: 1.5931785
# vis: 16
# weather: {'icon': 'c01d', 'description': 'Clear sky', 'code': 800}
# wind_cdir: S
# wind_cdir_full: south
# wind_dir: 190
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 11
# aqi: 78
# city_name: Sarajevo
# clouds: 7
# country_code: BA
# datetime: 2023-12-23:09
# dewpt: 3.8
# dhi: 76.16
# dni: 680.22
# elev_angle: 18.5
# ghi: 284.94
# gust: None
# h_angle: -22.5
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 09:30
# pod: d
# precip: 0
# pres: 947.1
# rh: 61
# slp: 1007
# snow: 0
# solar_rad: 284.9
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 11
# timezone: Europe/Sarajevo
# ts: 1703323800
# uv: 1.5931785
# vis: 16
# weather: {'icon': 'c01d', 'description': 'Clear sky', 'code': 800}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 11
# aqi: 80
# city_name: Sarajevo
# clouds: 37
# country_code: BA
# datetime: 2023-12-23:09
# dewpt: 3.8
# dhi: 82.98
# dni: 729.04
# elev_angle: 21.93
# ghi: 348.56
# gust: None
# h_angle: -22.5
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 09:38
# pod: d
# precip: 0
# pres: 947.1
# rh: 61
# slp: 1007
# snow: 0
# solar_rad: 339.1
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 11
# timezone: Europe/Sarajevo
# ts: 1703324324
# uv: 1.433884
# vis: 16
# weather: {'icon': 'c02d', 'description': 'Few clouds', 'code': 801}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 11
# aqi: 80
# city_name: Sarajevo
# clouds: 37
# country_code: BA
# datetime: 2023-12-23:10
# dewpt: 3.8
# dhi: 82.98
# dni: 729.04
# elev_angle: 21.93
# ghi: 348.56
# gust: None
# h_angle: 0
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 10:00
# pod: d
# precip: 0
# pres: 946.1
# rh: 61
# slp: 1006
# snow: 0
# solar_rad: 339.1
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 11
# timezone: Europe/Sarajevo
# ts: 1703325600
# uv: 1.433884
# vis: 16
# weather: {'icon': 'c02d', 'description': 'Few clouds', 'code': 801}
# wind_cdir: NNW
# wind_cdir_full: north-northwest
# wind_dir: 340
# wind_spd: 1.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 11
# aqi: 82
# city_name: Sarajevo
# clouds: 4
# country_code: BA
# datetime: 2023-12-23:10
# dewpt: 3.8
# dhi: 82.98
# dni: 729.04
# elev_angle: 21.93
# ghi: 348.56
# gust: None
# h_angle: 0
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 10:08
# pod: d
# precip: 0
# pres: 946.1
# rh: 61
# slp: 1006
# snow: 0
# solar_rad: 348.6
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 11
# timezone: Europe/Sarajevo
# ts: 1703326126
# uv: 1.8723094
# vis: 16
# weather: {'description': 'Clear sky', 'code': 800, 'icon': 'c01d'}
# wind_cdir: NNW
# wind_cdir_full: north-northwest
# wind_dir: 340
# wind_spd: 1.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 12
# aqi: 82
# city_name: Sarajevo
# clouds: 4
# country_code: BA
# datetime: 2023-12-23:10
# dewpt: 4
# dhi: 82.98
# dni: 729.04
# elev_angle: 21.93
# ghi: 348.56
# gust: None
# h_angle: 0
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 10:30
# pod: d
# precip: 0
# pres: 946.3
# rh: 58
# slp: 1006
# snow: 0
# solar_rad: 348.6
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 12
# timezone: Europe/Sarajevo
# ts: 1703327400
# uv: 1.8723094
# vis: 16
# weather: {'description': 'Clear sky', 'code': 800, 'icon': 'c01d'}
# wind_cdir: W
# wind_cdir_full: west
# wind_dir: 270
# wind_spd: 1.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 12
# aqi: 89
# city_name: Sarajevo
# clouds: 4
# country_code: BA
# datetime: 2023-12-23:10
# dewpt: 4
# dhi: 84.35
# dni: 738.45
# elev_angle: 22.68
# ghi: 362.37
# gust: None
# h_angle: 0
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 10:38
# pod: d
# precip: 0
# pres: 946.3
# rh: 58
# slp: 1006
# snow: 0
# solar_rad: 362.4
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 12
# timezone: Europe/Sarajevo
# ts: 1703327929
# uv: 1.9345614
# vis: 16
# weather: {'icon': 'c01d', 'description': 'Clear sky', 'code': 800}
# wind_cdir: W
# wind_cdir_full: west
# wind_dir: 270
# wind_spd: 1.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 13
# aqi: 89
# city_name: Sarajevo
# clouds: 4
# country_code: BA
# datetime: 2023-12-23:11
# dewpt: 2.8
# dhi: 84.35
# dni: 738.45
# elev_angle: 22.68
# ghi: 362.37
# gust: None
# h_angle: 22.5
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 11:00
# pod: d
# precip: 0
# pres: 946.5
# rh: 50
# slp: 1006
# snow: 0
# solar_rad: 362.4
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 13
# timezone: Europe/Sarajevo
# ts: 1703329200
# uv: 1.9345614
# vis: 16
# weather: {'icon': 'c01d', 'description': 'Clear sky', 'code': 800}
# wind_cdir: W
# wind_cdir_full: west
# wind_dir: 270
# wind_spd: 1.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 13
# aqi: 89
# city_name: Sarajevo
# clouds: 0
# country_code: BA
# datetime: 2023-12-23:11
# dewpt: 2.8
# dhi: 84.35
# dni: 738.45
# elev_angle: 22.68
# ghi: 362.37
# gust: None
# h_angle: 22.5
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 11:08
# pod: d
# precip: 0
# pres: 946.5
# rh: 50
# slp: 1006
# snow: 0
# solar_rad: 362.4
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 13
# timezone: Europe/Sarajevo
# ts: 1703329732
# uv: 1.9894707
# vis: 16
# weather: {'description': 'Clear sky', 'code': 800, 'icon': 'c01d'}
# wind_cdir: W
# wind_cdir_full: west
# wind_dir: 270
# wind_spd: 1.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 14
# aqi: 95
# city_name: Sarajevo
# clouds: 0
# country_code: BA
# datetime: 2023-12-23:11
# dewpt: 3.7
# dhi: 84.35
# dni: 738.45
# elev_angle: 22.68
# ghi: 362.37
# gust: None
# h_angle: 22.5
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 11:30
# pod: d
# precip: 0
# pres: 945.8
# rh: 50
# slp: 1005
# snow: 0
# solar_rad: 362.4
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 14
# timezone: Europe/Sarajevo
# ts: 1703331000
# uv: 1.9894707
# vis: 16
# weather: {'icon': 'c01d', 'description': 'Clear sky', 'code': 800}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 14
# aqi: 100
# city_name: Sarajevo
# clouds: 0
# country_code: BA
# datetime: 2023-12-23:11
# dewpt: 3.7
# dhi: 80.52
# dni: 711.78
# elev_angle: 20.64
# ghi: 324.6
# gust: None
# h_angle: 22.5
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 11:38
# pod: d
# precip: 0
# pres: 945.8
# rh: 50
# slp: 1005
# snow: 0
# solar_rad: 324.6
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 14
# timezone: Europe/Sarajevo
# ts: 1703331534
# uv: 1.822786
# vis: 16
# weather: {'icon': 'c01d', 'description': 'Clear sky', 'code': 800}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 14
# aqi: 100
# city_name: Sarajevo
# clouds: 0
# country_code: BA
# datetime: 2023-12-23:12
# dewpt: 2.9
# dhi: 80.52
# dni: 711.78
# elev_angle: 20.64
# ghi: 324.6
# gust: None
# h_angle: 45
# lat: 43.84864
# lon: 18.35644
# ...
# pres: 946.6
# rh: 66
# slp: 1007
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 9
# timezone: Europe/Sarajevo
# ts: 1703354400
# uv: 0
# vis: 16
# weather: {'code': 802, 'icon': 'c02n', 'description': 'Scattered clouds'}
# wind_cdir: NE
# wind_cdir_full: northeast
# wind_dir: 50
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 9
# aqi: 123
# city_name: Sarajevo
# clouds: 54
# country_code: BA
# datetime: 2023-12-23:18
# dewpt: 3
# dhi: 0
# dni: 0
# elev_angle: -29.02
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 18:09
# pod: n
# precip: 0
# pres: 946.6
# rh: 66
# slp: 1007
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 9
# timezone: Europe/Sarajevo
# ts: 1703354965
# uv: 0
# vis: 16
# weather: {'icon': 'c02n', 'description': 'Scattered clouds', 'code': 802}
# wind_cdir: NE
# wind_cdir_full: northeast
# wind_dir: 50
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 10
# aqi: 123
# city_name: Sarajevo
# clouds: 80
# country_code: BA
# datetime: 2023-12-23:18
# dewpt: 1.9
# dhi: 0
# dni: 0
# elev_angle: -29.02
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 18:30
# pod: n
# precip: 0
# pres: 946.8
# rh: 57
# slp: 1007
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 10
# timezone: Europe/Sarajevo
# ts: 1703356200
# uv: 0
# vis: 16
# weather: {'code': 803, 'icon': 'c03n', 'description': 'Broken clouds'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 10
# aqi: 161
# city_name: Sarajevo
# clouds: 82
# country_code: BA
# datetime: 2023-12-23:18
# dewpt: 1.9
# dhi: 0
# dni: 0
# elev_angle: -39.82
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 18:39
# pod: n
# precip: 0
# pres: 946.8
# rh: 57
# slp: 1007
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 10
# timezone: Europe/Sarajevo
# ts: 1703356767
# uv: 0
# vis: 16
# weather: {'icon': 'c03n', 'code': 803, 'description': 'Broken clouds'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 9
# aqi: 161
# city_name: Sarajevo
# clouds: 86
# country_code: BA
# datetime: 2023-12-23:19
# dewpt: 3
# dhi: 0
# dni: 0
# elev_angle: -39.82
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 19:00
# pod: n
# precip: 0
# pres: 947.6
# rh: 66
# slp: 1008
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 9
# timezone: Europe/Sarajevo
# ts: 1703358000
# uv: 0
# vis: 16
# weather: {'icon': 'c03n', 'code': 803, 'description': 'Broken clouds'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 9
# aqi: 161
# city_name: Sarajevo
# clouds: 86
# country_code: BA
# datetime: 2023-12-23:19
# dewpt: 3
# dhi: 0
# dni: 0
# elev_angle: -39.82
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 19:09
# pod: n
# precip: 0
# pres: 947.6
# rh: 66
# slp: 1008
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 9
# timezone: Europe/Sarajevo
# ts: 1703358569
# uv: 0
# vis: 16
# weather: {'code': 803, 'icon': 'c03n', 'description': 'Broken clouds'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 10
# aqi: 161
# city_name: Sarajevo
# clouds: 85
# country_code: BA
# datetime: 2023-12-23:19
# dewpt: 2.8
# dhi: 0
# dni: 0
# elev_angle: -39.82
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 19:30
# pod: n
# precip: 0
# pres: 947.8
# rh: 61
# slp: 1008
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 10
# timezone: Europe/Sarajevo
# ts: 1703359800
# uv: 0
# vis: 16
# weather: {'icon': 'c03n', 'description': 'Broken clouds', 'code': 803}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 10
# aqi: 160
# city_name: Sarajevo
# clouds: 85
# country_code: BA
# datetime: 2023-12-23:19
# dewpt: 2.8
# dhi: 0
# dni: 0
# elev_angle: -50.42
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 19:39
# pod: n
# precip: 0
# pres: 947.8
# rh: 61
# slp: 1008
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 10
# timezone: Europe/Sarajevo
# ts: 1703360371
# uv: 0
# vis: 16
# weather: {'icon': 'c03n', 'description': 'Broken clouds', 'code': 803}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 9
# aqi: 160
# city_name: Sarajevo
# clouds: 85
# country_code: BA
# datetime: 2023-12-23:20
# dewpt: 3
# dhi: 0
# dni: 0
# elev_angle: -50.42
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 20:00
# pod: n
# precip: 0
# pres: 948.5
# rh: 66
# slp: 1009
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 9
# timezone: Europe/Sarajevo
# ts: 1703361600
# uv: 0
# vis: 16
# weather: {'description': 'Broken clouds', 'code': 803, 'icon': 'c03n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 9
# aqi: 160
# city_name: Sarajevo
# clouds: 86
# country_code: BA
# datetime: 2023-12-23:20
# dewpt: 3
# dhi: 0
# dni: 0
# elev_angle: -50.42
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 20:09
# pod: n
# precip: 0
# pres: 948.5
# rh: 66
# slp: 1009
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 9
# timezone: Europe/Sarajevo
# ts: 1703362173
# uv: 0
# vis: 16
# weather: {'description': 'Broken clouds', 'code': 803, 'icon': 'c03n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 9
# aqi: 160
# city_name: Sarajevo
# clouds: 86
# country_code: BA
# datetime: 2023-12-23:20
# dewpt: 3
# dhi: 0
# dni: 0
# elev_angle: -50.42
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 20:24
# pod: n
# precip: 0
# pres: 948.5
# rh: 66
# slp: 1009
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 9
# timezone: Europe/Sarajevo
# ts: 1703363074
# uv: 0
# vis: 16
# weather: {'description': 'Broken clouds', 'code': 803, 'icon': 'c03n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 9
# aqi: 159
# city_name: Sarajevo
# clouds: 86
# country_code: BA
# datetime: 2023-12-23:20
# dewpt: 3
# dhi: 0
# dni: 0
# elev_angle: -60.17
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 20:39
# pod: n
# precip: 0
# pres: 948.5
# rh: 66
# slp: 1009
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 9
# timezone: Europe/Sarajevo
# ts: 1703363975
# uv: 0
# vis: 16
# weather: {'icon': 'c03n', 'description': 'Broken clouds', 'code': 803}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 9
# aqi: 156
# city_name: Sarajevo
# clouds: 87
# country_code: BA
# datetime: 2023-12-23:20
# dewpt: 3
# dhi: 0
# dni: 0
# elev_angle: -60.17
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 20:54
# pod: n
# precip: 0
# pres: 948.5
# rh: 66
# slp: 1009
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 9
# timezone: Europe/Sarajevo
# ts: 1703364876
# uv: 0
# vis: 16
# weather: {'icon': 'c03n', 'description': 'Broken clouds', 'code': 803}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 9
# aqi: 156
# city_name: Sarajevo
# clouds: 87
# country_code: BA
# datetime: 2023-12-23:21
# dewpt: 3.8
# dhi: 0
# dni: 0
# elev_angle: -60.17
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 21:09
# pod: n
# precip: 0
# pres: 948.5
# rh: 70
# slp: 1009
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 9
# timezone: Europe/Sarajevo
# ts: 1703365777
# uv: 0
# vis: 16
# weather: {'description': 'Broken clouds', 'code': 803, 'icon': 'c03n'}
# wind_cdir: ENE
# wind_cdir_full: east-northeast
# wind_dir: 60
# wind_spd: 2.1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 9
# aqi: 156
# city_name: Sarajevo
# clouds: 88
# country_code: BA
# datetime: 2023-12-23:21
# dewpt: 3.8
# dhi: 0
# dni: 0
# elev_angle: -60.17
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 21:30
# pod: n
# precip: 0
# pres: 948.5
# rh: 70
# slp: 1009
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 9
# timezone: Europe/Sarajevo
# ts: 1703367000
# uv: 0
# vis: 16
# weather: {'icon': 'c03n', 'description': 'Broken clouds', 'code': 803}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 9
# aqi: 155
# city_name: Sarajevo
# clouds: 88
# country_code: BA
# datetime: 2023-12-23:21
# dewpt: 3.8
# dhi: 0
# dni: 0
# elev_angle: -67.49
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 21:39
# pod: n
# precip: 0
# pres: 948.5
# rh: 70
# slp: 1009
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 9
# timezone: Europe/Sarajevo
# ts: 1703367579
# uv: 0
# vis: 16
# weather: {'icon': 'c03n', 'description': 'Broken clouds', 'code': 803}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 9
# aqi: 155
# city_name: Sarajevo
# clouds: 89
# country_code: BA
# datetime: 2023-12-23:22
# dewpt: 3.8
# dhi: 0
# dni: 0
# elev_angle: -67.49
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 22:00
# pod: n
# precip: 0
# pres: 949.5
# rh: 70
# slp: 1010
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 9
# timezone: Europe/Sarajevo
# ts: 1703368800
# uv: 0
# vis: 16
# weather: {'icon': 'c03n', 'description': 'Broken clouds', 'code': 803}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 9
# aqi: 155
# city_name: Sarajevo
# clouds: 88
# country_code: BA
# datetime: 2023-12-23:22
# dewpt: 3.8
# dhi: 0
# dni: 0
# elev_angle: -67.49
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 22:09
# pod: n
# precip: 0
# pres: 949.5
# rh: 70
# slp: 1010
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 9
# timezone: Europe/Sarajevo
# ts: 1703369381
# uv: 0
# vis: 16
# weather: {'code': 803, 'icon': 'c03n', 'description': 'Broken clouds'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 8
# aqi: 155
# city_name: Sarajevo
# clouds: 88
# country_code: BA
# datetime: 2023-12-23:22
# dewpt: 3.8
# dhi: 0
# dni: 0
# elev_angle: -67.49
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 22:30
# pod: n
# precip: 0
# pres: 949.3
# rh: 75
# slp: 1010
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 8
# timezone: Europe/Sarajevo
# ts: 1703370600
# uv: 0
# vis: 16
# weather: {'icon': 'c03n', 'description': 'Broken clouds', 'code': 803}
# wind_cdir: ESE
# wind_cdir_full: east-southeast
# wind_dir: 120
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-23
#
# app_temp: 8
# aqi: 155
# city_name: Sarajevo
# clouds: 88
# country_code: BA
# datetime: 2023-12-23:22
# dewpt: 3.8
# dhi: 0
# dni: 0
# elev_angle: -69.39
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 22:39
# pod: n
# precip: 0
# pres: 949.3
# rh: 75
# slp: 1010
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 8
# timezone: Europe/Sarajevo
# ts: 1703371182
# uv: 0
# vis: 16
# weather: {'description': 'Broken clouds', 'code': 803, 'icon': 'c03n'}
# wind_cdir: ESE
# wind_cdir_full: east-southeast
# wind_dir: 120
# wind_spd: 1
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-24
#
# app_temp: 6.3
# aqi: 155
# city_name: Sarajevo
# clouds: 87
# country_code: BA
# datetime: 2023-12-23:23
# dewpt: 4
# dhi: 0
# dni: 0
# elev_angle: -69.39
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 23:00
# pod: n
# precip: 0
# pres: 949
# rh: 81
# slp: 1010
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 7
# timezone: Europe/Sarajevo
# ts: 1703372400
# uv: 0
# vis: 16
# weather: {'code': 803, 'icon': 'c03n', 'description': 'Broken clouds'}
# wind_cdir: SE
# wind_cdir_full: southeast
# wind_dir: 140
# wind_spd: 1.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-24
#
# app_temp: 6.3
# aqi: 155
# city_name: Sarajevo
# clouds: 87
# country_code: BA
# datetime: 2023-12-23:23
# dewpt: 4
# dhi: 0
# dni: 0
# elev_angle: -69.39
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 23:09
# pod: n
# precip: 0
# pres: 949
# rh: 81
# slp: 1010
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 7
# timezone: Europe/Sarajevo
# ts: 1703372985
# uv: 0
# vis: 16
# weather: {'code': 803, 'icon': 'c03n', 'description': 'Broken clouds'}
# wind_cdir: SE
# wind_cdir_full: southeast
# wind_dir: 140
# wind_spd: 1.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-24
#
# app_temp: 8.1
# aqi: 155
# city_name: Sarajevo
# clouds: 88
# country_code: BA
# datetime: 2023-12-23:23
# dewpt: 4
# dhi: 0
# dni: 0
# elev_angle: -69.39
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 23:30
# pod: n
# precip: 0
# pres: 949
# rh: 81
# slp: 1010
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 7
# timezone: Europe/Sarajevo
# ts: 1703374200
# uv: 0
# vis: 16
# weather: {'icon': 'c03n', 'description': 'Broken clouds', 'code': 803}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 0.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-24
#
# app_temp: 8.1
# aqi: 156
# city_name: Sarajevo
# clouds: 88
# country_code: BA
# datetime: 2023-12-23:23
# dewpt: 4
# dhi: 0
# dni: 0
# elev_angle: -64.58
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-23 23:39
# pod: n
# precip: 0
# pres: 949
# rh: 81
# slp: 1010
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 7
# timezone: Europe/Sarajevo
# ts: 1703374787
# uv: 0
# vis: 16
# weather: {'icon': 'c03n', 'description': 'Broken clouds', 'code': 803}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 0.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-24
#
# app_temp: 8.1
# aqi: 156
# city_name: Sarajevo
# clouds: 88
# country_code: BA
# datetime: 2023-12-24:00
# dewpt: 5
# dhi: 0
# dni: 0
# elev_angle: -64.58
# ghi: 0
# gust: None
# h_angle: -90
# lat: 43.84864
# lon: 18.35644
# ob_time: 2023-12-24 00:00
# pod: n
# precip: 0
# pres: 950
# rh: 87
# slp: 1011
# snow: 0
# solar_rad: 0
# sources: ['LQSA', 'radar', 'satellite']
# state_code: 01
# station: LQSA
# sunrise: 06:18
# sunset: 15:13
# temp: 7
# timezone: Europe/Sarajevo
# ts: 1703376000
# uv: 0
# vis: 16
# weather: {'description': 'Broken clouds', 'code': 803, 'icon': 'c03n'}
# wind_cdir: N
# wind_cdir_full: north
# wind_dir: 0
# wind_spd: 0.5
#
# ----------------------------------------
#
#
# Novi dan: 2023-12-24
